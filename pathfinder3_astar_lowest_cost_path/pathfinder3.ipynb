# %%
from heapq import heappop, heappush, heapify

def calc_manhattan_distance(p1,p2):
    x1,y1 = p1
    x2,y2 = p2
    return(abs(x1-x2)+abs(y1-y2))

class Maze():
    def __init__(self, maze_grid):
        self.maze_grid = maze_grid
        self.maze_list = self.maze_unpack(maze_grid)
        self.start = [0,0]
        self.length = len(self.maze_list)
        self.finish = [self.length-1,self.length-1]
        self.start_value = int(self.maze_list[0][0])
        
    def get_adjacent_cells(self, Node):
        
        maze = self.maze_list
        maze_l = self.length
        
        x,y = Node.coord
        cng = Node.value
        
        def cngdf(val):
            return(abs(int(val) - int(cng)))
        
        adj_cells = [] #list of lists [[new x, new y, cost of move, value from maze],[...],...]
        #check right
        if x + 1 < maze_l : adj_cells.append([x+1, y, cngdf(maze[y][x+1]),maze[y][x+1]])
        #check left
        if x - 1 >= 0 : adj_cells.append([x-1, y, cngdf(maze[y][x-1]),maze[y][x-1]])
        #check down
        if y + 1 < maze_l : adj_cells.append([x, y + 1, cngdf(maze[y + 1][x]),maze[y + 1][x]])
        #check up
        if y - 1 >= 0 : adj_cells.append([x, y-1, cngdf(maze[y-1][x]),maze[y-1][x]])
        return(adj_cells)
    
    #take maze from codewars format into list of lists
    def maze_unpack(self, maze_grid):
        return(maze_grid)
        #return([list(i) for i in  self.maze_grid.split('\n')])


class Node():
    def __init__(self, coord, maze, g, value):
        self.x = coord[0]
        self.y = coord[1]
        self.g = g
        self.value = value
        self.h = calc_manhattan_distance(coord, maze.finish)
        self.coord = coord
        self.parent = None
        self.coord_t = tuple(coord)
        
    #compute total costs from start plus estimated costs to finish
    def f(self):
        return(self.g + self.h)
    
def retrace_path(node):
    total = node.g
    while node.coord !=[0,0]:
        print(node.coord)
        print(total - node.g)
        print(node.g)
        print(node.value)
        print("******")
        node = node.parent
    
def path_finder(maze):
    closed = set() #closed coords
    frontier = [] #heap of costs and node coordinates
    node_finder = {} #dict of coords and node objs #node_finder[coord] = Node obj
    
    maze = Maze(maze)
    #print(maze.maze_list)
    start_node = Node([0,0], maze, 0, maze.start_value)
    
    #push a list of [costs, [x,y]]
    heappush(frontier, [start_node.f(), start_node.coord])
    
    #add coords to lookup dict to ref node object
    node_finder[start_node.coord_t] = start_node
    
    #while we have nodes...
    while frontier:
        
        #pop the cheapest node off for testing
        current_node = heappop(frontier)
        current_node = node_finder[tuple(current_node[1])]
        
        print("current_node coord = %s" % current_node.coord)
        print("current_node value = %s" % current_node.value)
        print("current_node g = %s" % current_node.g)
        print("current_node h = %s" % current_node.h)
        print("current_node f = %s" % current_node.f())
        print("\n")
              
        #if at finish coords
        if current_node.coord == maze.finish:
            print(retrace_path(current_node))
            print(current_node.g)
            return(current_node.g)
        
        #add the coords to our closed/visited/seen set
        closed.add(current_node.coord_t)
        
        #make a list of valid neighbors to visit, only major cardinal directions with no walls
        adj_nodes = [Node(i[0:2], maze, i[2], i[3]) for i in maze.get_adjacent_cells(current_node)]
        
        for node in adj_nodes:   
            
            #if already tested node, skip
            if tuple(node.coord_t) in closed:
                continue            
            
            #else evaluate
            else:
                print("coord = %s" % node.coord)
                print("value = %s" % node.value)
                print("g = %s" % node.g)
                print("h = %s" % node.h)
                print("f = %s" % node.f())
            
                #add cost of move to this neighbor node to the cost of the total path here
                node.g = current_node.g + node.g
                print("new node g = %s" % node.g)
                print("\n")
                
                #record parent node
                node.parent = current_node
                
                #check the dict to see if this total cost is less than the existing path cost to this node
                #if so, replace the node details and add the new details to the frontier
                if node.coord_t in node_finder:
                    old_node_g = node_finder[node.coord_t].g
                    old_node_f = node_finder[node.coord_t].f()
                    if node.g < old_node_g:
                        node_finder[node.coord_t] = node
                        index_node_match = frontier.index([old_node_f, node.coord]) # get the index of node on frontier so f can be replaced
                        print("*Faster Path* = %s" % frontier.index([old_node_f, node.coord]))
                        frontier[index_node_match] = [node.f(), node.coord] # replace the f value with shorter one and same node coords
                        heapify(frontier)
                        
                        #could also just push onto heap again
                        #heappush(frontier, [node.f(), node.coord])
                        
                #otherwise, add neighbor nodes to the dict and to the frontier for further exploration
                else:
                    node_finder[node.coord_t] = node
                    heappush(frontier, [node.f(), node.coord])
    return(False)

# %% [markdown]
# #should = 72, equals 74 instead.  passes 149 of 151 randomized test cases
# a=[['6', '5', '9', '2', '3', '5', '5', '1', '0', '3', '8', '2', '1', '0', '6', '4', '1', '7', '1', '4', '5', '7', '1', '3', '1', '2', '2', '0'],
#    ['1', '6', '0', '7', '5', '1', '0', '1', '8', '4', '9', '6', '8', '5', '2', '9', '7', '1', '2', '4', '3', '3', '1', '9', '1', '1', '6', '9'],
#    ['0', '6', '5', '2', '3', '9', '3', '5', '1', '9', '0', '3', '4', '3', '8', '8', '6', '6', '5', '0', '6', '0', '8', '3', '5', '8', '2', '0'],
#    ['0', '4', '8', '4', '4', '7', '6', '3', '2', '1', '2', '9', '1', '5', '2', '7', '0', '9', '4', '9', '1', '9', '4', '7', '3', '5', '0', '7'],
#    ['9', '4', '1', '8', '2', '7', '3', '6', '2', '8', '0', '1', '5', '5', '4', '4', '5', '8', '9', '6', '3', '6', '2', '3', '5', '2', '1', '9'],
#    ['0', '1', '7', '6', '2', '5', '9', '6', '9', '4', '1', '0', '3', '9', '8', '7', '5', '9', '1', '5', '1', '6', '3', '6', '5', '5', '9', '7'],
#    ['4', '2', '3', '9', '2', '8', '5', '9', '0', '2', '7', '3', '1', '9', '5', '1', '8', '3', '1', '7', '7', '7', '5', '7', '5', '9', '7', '8'],
#    ['5', '1', '9', '7', '1', '8', '0', '1', '0', '3', '1', '1', '9', '2', '2', '6', '5', '2', '9', '0', '5', '6', '8', '6', '7', '0', '1', '9'],
#    ['2', '2', '1', '0', '1', '4', '8', '8', '5', '1', '7', '2', '2', '9', '8', '2', '3', '3', '1', '3', '2', '3', '1', '0', '6', '1', '4', '5'],
#    ['5', '9', '5', '6', '5', '1', '9', '3', '3', '3', '4', '5', '4', '1', '5', '5', '4', '1', '0', '4', '1', '9', '7', '4', '4', '1', '6', '8'],
#    ['6', '1', '3', '1', '3', '9', '0', '9', '2', '2', '7', '7', '9', '9', '0', '4', '6', '7', '7', '5', '8', '4', '3', '1', '2', '3', '7', '1'],
#    ['0', '8', '0', '1', '4', '2', '1', '3', '0', '4', '9', '9', '0', '7', '8', '9', '7', '7', '2', '2', '7', '7', '6', '5', '9', '5', '2', '5'],
#    ['6', '4', '0', '4', '4', '8', '6', '8', '1', '2', '2', '8', '3', '7', '9', '7', '4', '6', '5', '0', '0', '9', '6', '6', '1', '3', '1', '8'],
#    ['4', '7', '2', '7', '5', '3', '0', '0', '2', '1', '4', '6', '2', '2', '6', '5', '9', '8', '7', '8', '6', '2', '2', '9', '2', '6', '6', '8'],
#    ['6', '0', '6', '0', '7', '4', '2', '2', '0', '9', '6', '3', '8', '5', '2', '8', '3', '1', '5', '4', '3', '8', '2', '1', '6', '1', '3', '0'],
#    ['2', '9', '2', '1', '0', '5', '5', '1', '7', '2', '7', '0', '6', '2', '9', '8', '2', '5', '6', '2', '4', '6', '9', '5', '7', '8', '9', '4'],
#    ['0', '1', '2', '7', '5', '4', '2', '0', '8', '5', '9', '0', '8', '3', '0', '9', '1', '4', '1', '7', '6', '2', '9', '3', '8', '2', '8', '6'],
#    ['4', '8', '1', '8', '4', '1', '5', '7', '9', '9', '1', '5', '5', '5', '4', '0', '0', '4', '8', '5', '1', '0', '1', '7', '8', '1', '6', '5'],
#    ['7', '5', '7', '8', '9', '5', '9', '3', '7', '0', '6', '1', '0', '1', '7', '0', '9', '4', '9', '8', '3', '3', '0', '0', '7', '4', '3', '3'],
#    ['5', '6', '7', '0', '3', '6', '5', '4', '6', '2', '6', '2', '1', '0', '9', '9', '5', '5', '7', '2', '9', '7', '5', '7', '4', '0', '2', '7'],
#    ['0', '8', '8', '4', '4', '1', '6', '1', '6', '0', '7', '3', '3', '4', '6', '3', '7', '8', '5', '6', '3', '6', '8', '3', '5', '5', '7', '2'],
#    ['3', '2', '6', '6', '6', '9', '4', '2', '4', '0', '9', '9', '6', '0', '8', '7', '9', '7', '1', '4', '9', '2', '8', '8', '1', '9', '5', '1'],
#    ['2', '5', '5', '9', '6', '5', '4', '6', '8', '6', '5', '0', '0', '4', '6', '8', '8', '0', '9', '5', '5', '2', '2', '3', '3', '3', '3', '0'],
#    ['3', '2', '9', '4', '0', '2', '7', '9', '8', '0', '5', '0', '8', '0', '5', '5', '3', '9', '6', '3', '5', '5', '4', '8', '5', '8', '9', '1'],
#    ['5', '8', '6', '4', '0', '2', '7', '3', '7', '1', '1', '5', '3', '5', '2', '5', '5', '1', '6', '6', '3', '8', '9', '7', '9', '9', '7', '1'],
#    ['9', '9', '2', '6', '0', '9', '8', '8', '2', '2', '6', '3', '9', '3', '3', '7', '3', '7', '8', '8', '8', '6', '8', '8', '2', '5', '4', '9'],
#    ['2', '1', '4', '0', '2', '6', '5', '0', '9', '9', '7', '4', '2', '8', '5', '8', '8', '5', '6', '3', '2', '2', '0', '2', '5', '5', '8', '9'],
#    ['5', '4', '2', '6', '2', '8', '3', '9', '8', '0', '5', '3', '7', '7', '6', '5', '2', '0', '4', '0', '9', '1', '9', '5', '7', '1', '3', '4']]

# %%
#59 should be 57
a = [['2', '8', '1', '9', '9', '5', '0', '4', '9', '0', '4', '9', '4', '7', '5', '2', '2', '8', '8', '9', '1'], 
     ['2', '4', '6', '0', '9', '5', '4', '2', '3', '4', '4', '8', '8', '0', '4', '3', '1', '4', '2', '4', '8'], 
     ['4', '8', '1', '3', '3', '2', '0', '4', '3', '3', '9', '3', '7', '4', '1', '7', '7', '8', '7', '9', '9'], 
     ['8', '6', '9', '3', '8', '3', '8', '8', '1', '7', '4', '1', '2', '7', '2', '0', '9', '9', '0', '7', '3'], 
     ['3', '5', '1', '7', '2', '2', '4', '8', '8', '2', '0', '2', '0', '4', '0', '0', '5', '7', '9', '3', '9'], 
     ['4', '1', '2', '7', '6', '4', '9', '3', '7', '4', '0', '5', '0', '6', '3', '9', '6', '6', '4', '2', '3'], 
     ['8', '7', '6', '5', '3', '5', '0', '0', '9', '3', '8', '8', '3', '3', '7', '3', '2', '7', '9', '5', '5'], 
     ['2', '6', '1', '4', '2', '4', '6', '9', '3', '9', '3', '1', '6', '1', '9', '7', '2', '8', '7', '8', '7'], 
     ['6', '9', '6', '4', '4', '4', '2', '8', '2', '0', '6', '5', '2', '2', '3', '2', '9', '2', '9', '1', '6'], 
     ['0', '9', '9', '9', '9', '0', '0', '3', '2', '7', '2', '3', '2', '0', '5', '6', '1', '6', '1', '1', '8'], 
     ['6', '5', '2', '8', '8', '4', '7', '7', '9', '4', '0', '7', '3', '4', '1', '6', '2', '6', '0', '1', '8'], 
     ['7', '7', '2', '7', '7', '6', '3', '0', '0', '1', '0', '5', '1', '3', '9', '1', '3', '1', '9', '2', '8'], 
     ['5', '8', '3', '1', '4', '8', '0', '9', '5', '9', '9', '8', '6', '5', '4', '0', '6', '2', '9', '4', '9'], 
     ['9', '0', '3', '7', '8', '9', '1', '1', '0', '1', '1', '8', '0', '3', '0', '6', '7', '3', '9', '5', '1'], 
     ['8', '7', '8', '1', '1', '7', '4', '4', '6', '1', '0', '6', '7', '6', '1', '1', '4', '0', '9', '6', '9'], 
     ['0', '3', '3', '2', '5', '9', '0', '3', '1', '9', '8', '3', '5', '1', '8', '4', '3', '2', '4', '0', '4'], 
     ['1', '7', '9', '5', '2', '3', '7', '9', '6', '0', '0', '7', '9', '0', '1', '8', '7', '7', '8', '8', '0'], 
     ['3', '8', '1', '4', '2', '7', '9', '7', '3', '5', '1', '3', '9', '1', '6', '3', '1', '0', '6', '8', '1'],
     ['3', '5', '0', '6', '2', '9', '7', '3', '0', '9', '7', '4', '9', '8', '7', '1', '1', '5', '3', '1', '3'], 
     ['6', '9', '5', '9', '3', '8', '8', '9', '9', '6', '9', '2', '2', '9', '4', '5', '6', '5', '3', '7', '4'], 
     ['2', '1', '1', '1', '3', '3', '7', '0', '8', '1', '5', '5', '0', '9', '4', '0', '6', '5', '6', '6', '7']]

# %%
print(path_finder(a))
# Out:
# current_node coord = [0, 0]
# current_node value = 2
# current_node g = 0
# current_node h = 40
# current_node f = 40
#
#
# coord = [1, 0]
# value = 8
# g = 6
# h = 39
# f = 45
# new node g = 6
#
#
# coord = [0, 1]
# value = 2
# g = 0
# h = 39
# f = 39
# new node g = 0
#
#
# current_node coord = [0, 1]
# current_node value = 2
# current_node g = 0
# current_node h = 39
# current_node f = 39
#
#
# coord = [1, 1]
# value = 4
# g = 2
# h = 38
# f = 40
# new node g = 2
#
#
# coord = [0, 2]
# value = 4
# g = 2
# h = 38
# f = 40
# new node g = 2
#
#
# current_node coord = [0, 2]
# current_node value = 4
# current_node g = 2
# current_node h = 38
# current_node f = 40
#
#
# coord = [1, 2]
# value = 8
# g = 4
# h = 37
# f = 41
# new node g = 6
#
#
# coord = [0, 3]
# value = 8
# g = 4
# h = 37
# f = 41
# new node g = 6
#
#
# current_node coord = [1, 1]
# current_node value = 4
# current_node g = 2
# current_node h = 38
# current_node f = 40
#
#
# coord = [2, 1]
# value = 6
# g = 2
# h = 37
# f = 39
# new node g = 4
#
#
# coord = [1, 2]
# value = 8
# g = 4
# h = 37
# f = 41
# new node g = 6
#
#
# coord = [1, 0]
# value = 8
# g = 4
# h = 39
# f = 43
# new node g = 6
#
#
# current_node coord = [2, 1]
# current_node value = 6
# current_node g = 4
# current_node h = 37
# current_node f = 41
#
#
# coord = [3, 1]
# value = 0
# g = 6
# h = 36
# f = 42
# new node g = 10
#
#
# coord = [2, 2]
# value = 1
# g = 5
# h = 36
# f = 41
# new node g = 9
#
#
# coord = [2, 0]
# value = 1
# g = 5
# h = 38
# f = 43
# new node g = 9
#
#
# current_node coord = [0, 3]
# current_node value = 8
# current_node g = 6
# current_node h = 37
# current_node f = 43
#
#
# coord = [1, 3]
# value = 6
# g = 2
# h = 36
# f = 38
# new node g = 8
#
#
# coord = [0, 4]
# value = 3
# g = 5
# h = 36
# f = 41
# new node g = 11
#
#
# current_node coord = [1, 2]
# current_node value = 8
# current_node g = 6
# current_node h = 37
# current_node f = 43
#
#
# coord = [2, 2]
# value = 1
# g = 7
# h = 36
# f = 43
# new node g = 13
#
#
# coord = [1, 3]
# value = 6
# g = 2
# h = 36
# f = 38
# new node g = 8
#
#
# current_node coord = [1, 3]
# current_node value = 6
# current_node g = 8
# current_node h = 36
# current_node f = 44
#
#
# coord = [2, 3]
# value = 9
# g = 3
# h = 35
# f = 38
# new node g = 11
#
#
# coord = [1, 4]
# value = 5
# g = 1
# h = 35
# f = 36
# new node g = 9
#
#
# current_node coord = [1, 4]
# current_node value = 5
# current_node g = 9
# current_node h = 35
# current_node f = 44
#
#
# coord = [2, 4]
# value = 1
# g = 4
# h = 34
# f = 38
# new node g = 13
#
#
# coord = [0, 4]
# value = 3
# g = 2
# h = 36
# f = 38
# new node g = 11
#
#
# coord = [1, 5]
# value = 1
# g = 4
# h = 34
# f = 38
# new node g = 13
#
#
# current_node coord = [1, 0]
# current_node value = 8
# current_node g = 6
# current_node h = 39
# current_node f = 45
#
#
# coord = [2, 0]
# value = 1
# g = 7
# h = 38
# f = 45
# new node g = 13
#
#
# current_node coord = [2, 2]
# current_node value = 1
# current_node g = 9
# current_node h = 36
# current_node f = 45
#
#
# coord = [3, 2]
# value = 3
# g = 2
# h = 35
# f = 37
# new node g = 11
#
#
# coord = [2, 3]
# value = 9
# g = 8
# h = 35
# f = 43
# new node g = 17
#
#
# current_node coord = [2, 3]
# current_node value = 9
# current_node g = 11
# current_node h = 35
# current_node f = 46
#
#
# coord = [3, 3]
# value = 3
# g = 6
# h = 34
# f = 40
# new node g = 17
#
#
# coord = [2, 4]
# value = 1
# g = 8
# h = 34
# f = 42
# new node g = 19
#
#
# current_node coord = [3, 1]
# current_node value = 0
# current_node g = 10
# current_node h = 36
# current_node f = 46
#
#
# coord = [4, 1]
# value = 9
# g = 9
# h = 35
# f = 44
# new node g = 19
#
#
# coord = [3, 2]
# value = 3
# g = 3
# h = 35
# f = 38
# new node g = 13
#
#
# coord = [3, 0]
# value = 9
# g = 9
# h = 37
# f = 46
# new node g = 19
#
#
# current_node coord = [3, 2]
# current_node value = 3
# current_node g = 11
# current_node h = 35
# current_node f = 46
#
#
# coord = [4, 2]
# value = 3
# g = 0
# h = 34
# f = 34
# new node g = 11
#
#
# coord = [3, 3]
# value = 3
# g = 0
# h = 34
# f = 34
# new node g = 11
#
#
# *Faster Path* = 5
# current_node coord = [3, 3]
# current_node value = 3
# current_node g = 11
# current_node h = 34
# current_node f = 45
#
#
# coord = [4, 3]
# value = 8
# g = 5
# h = 33
# f = 38
# new node g = 16
#
#
# coord = [3, 4]
# value = 7
# g = 4
# h = 33
# f = 37
# new node g = 15
#
#
# current_node coord = [4, 2]
# current_node value = 3
# current_node g = 11
# current_node h = 34
# current_node f = 45
#
#
# coord = [5, 2]
# value = 2
# g = 1
# h = 33
# f = 34
# new node g = 12
#
#
# coord = [4, 3]
# value = 8
# g = 5
# h = 33
# f = 38
# new node g = 16
#
#
# coord = [4, 1]
# value = 9
# g = 6
# h = 35
# f = 41
# new node g = 17
#
#
# *Faster Path* = 6
# current_node coord = [5, 2]
# current_node value = 2
# current_node g = 12
# current_node h = 33
# current_node f = 45
#
#
# coord = [6, 2]
# value = 0
# g = 2
# h = 32
# f = 34
# new node g = 14
#
#
# coord = [5, 3]
# value = 3
# g = 1
# h = 32
# f = 33
# new node g = 13
#
#
# coord = [5, 1]
# value = 5
# g = 3
# h = 34
# f = 37
# new node g = 15
#
#
# current_node coord = [5, 3]
# current_node value = 3
# current_node g = 13
# current_node h = 32
# current_node f = 45
#
#
# coord = [6, 3]
# value = 8
# g = 5
# h = 31
# f = 36
# new node g = 18
#
#
# coord = [4, 3]
# value = 8
# g = 5
# h = 33
# f = 38
# new node g = 18
#
#
# coord = [5, 4]
# value = 2
# g = 1
# h = 31
# f = 32
# new node g = 14
#
#
# current_node coord = [5, 4]
# current_node value = 2
# current_node g = 14
# current_node h = 31
# current_node f = 45
#
#
# coord = [6, 4]
# value = 4
# g = 2
# h = 30
# f = 32
# new node g = 16
#
#
# coord = [4, 4]
# value = 2
# g = 0
# h = 32
# f = 32
# new node g = 14
#
#
# coord = [5, 5]
# value = 4
# g = 2
# h = 30
# f = 32
# new node g = 16
#
#
# current_node coord = [4, 4]
# current_node value = 2
# current_node g = 14
# current_node h = 32
# current_node f = 46
#
#
# coord = [3, 4]
# value = 7
# g = 5
# h = 33
# f = 38
# new node g = 19
#
#
# coord = [4, 5]
# value = 6
# g = 4
# h = 31
# f = 35
# new node g = 18
#
#
# coord = [4, 3]
# value = 8
# g = 6
# h = 33
# f = 39
# new node g = 20
#
#
# current_node coord = [5, 5]
# current_node value = 4
# current_node g = 16
# current_node h = 30
# current_node f = 46
#
#
# coord = [6, 5]
# value = 9
# g = 5
# h = 29
# f = 34
# new node g = 21
#
#
# coord = [4, 5]
# value = 6
# g = 2
# h = 31
# f = 33
# new node g = 18
#
#
# coord = [5, 6]
# value = 5
# g = 1
# h = 29
# f = 30
# new node g = 17
#
#
# current_node coord = [5, 6]
# current_node value = 5
# current_node g = 17
# current_node h = 29
# current_node f = 46
#
#
# coord = [6, 6]
# value = 0
# g = 5
# h = 28
# f = 33
# new node g = 22
#
#
# coord = [4, 6]
# value = 3
# g = 2
# h = 30
# f = 32
# new node g = 19
#
#
# coord = [5, 7]
# value = 4
# g = 1
# h = 28
# f = 29
# new node g = 18
#
#
# current_node coord = [5, 7]
# current_node value = 4
# current_node g = 18
# current_node h = 28
# current_node f = 46
#
#
# coord = [6, 7]
# value = 6
# g = 2
# h = 27
# f = 29
# new node g = 20
#
#
# coord = [4, 7]
# value = 2
# g = 2
# h = 29
# f = 31
# new node g = 20
#
#
# coord = [5, 8]
# value = 4
# g = 0
# h = 27
# f = 27
# new node g = 18
#
#
# current_node coord = [5, 8]
# current_node value = 4
# current_node g = 18
# current_node h = 27
# current_node f = 45
#
#
# coord = [6, 8]
# value = 2
# g = 2
# h = 26
# f = 28
# new node g = 20
#
#
# coord = [4, 8]
# value = 4
# g = 0
# h = 28
# f = 28
# new node g = 18
#
#
# coord = [5, 9]
# value = 0
# g = 4
# h = 26
# f = 30
# new node g = 22
#
#
# current_node coord = [4, 8]
# current_node value = 4
# current_node g = 18
# current_node h = 28
# current_node f = 46
#
#
# coord = [3, 8]
# value = 4
# g = 0
# h = 29
# f = 29
# new node g = 18
#
#
# coord = [4, 9]
# value = 9
# g = 5
# h = 27
# f = 32
# new node g = 23
#
#
# coord = [4, 7]
# value = 2
# g = 2
# h = 29
# f = 31
# new node g = 20
#
#
# current_node coord = [6, 2]
# current_node value = 0
# current_node g = 14
# current_node h = 32
# current_node f = 46
#
#
# coord = [7, 2]
# value = 4
# g = 4
# h = 31
# f = 35
# new node g = 18
#
#
# coord = [6, 3]
# value = 8
# g = 8
# h = 31
# f = 39
# new node g = 22
#
#
# coord = [6, 1]
# value = 4
# g = 4
# h = 33
# f = 37
# new node g = 18
#
#
# current_node coord = [6, 4]
# current_node value = 4
# current_node g = 16
# current_node h = 30
# current_node f = 46
#
#
# coord = [7, 4]
# value = 8
# g = 4
# h = 29
# f = 33
# new node g = 20
#
#
# coord = [6, 5]
# value = 9
# g = 5
# h = 29
# f = 34
# new node g = 21
#
#
# coord = [6, 3]
# value = 8
# g = 4
# h = 31
# f = 35
# new node g = 20
#
#
# current_node coord = [6, 8]
# current_node value = 2
# current_node g = 20
# current_node h = 26
# current_node f = 46
#
#
# coord = [7, 8]
# value = 8
# g = 6
# h = 25
# f = 31
# new node g = 26
#
#
# coord = [6, 9]
# value = 0
# g = 2
# h = 25
# f = 27
# new node g = 22
#
#
# coord = [6, 7]
# value = 6
# g = 4
# h = 27
# f = 31
# new node g = 24
#
#
# current_node coord = [0, 4]
# current_node value = 3
# current_node g = 11
# current_node h = 36
# current_node f = 47
#
#
# coord = [0, 5]
# value = 4
# g = 1
# h = 35
# f = 36
# new node g = 12
#
#
# current_node coord = [0, 5]
# current_node value = 4
# current_node g = 12
# current_node h = 35
# current_node f = 47
#
#
# coord = [1, 5]
# value = 1
# g = 3
# h = 34
# f = 37
# new node g = 15
#
#
# coord = [0, 6]
# value = 8
# g = 4
# h = 34
# f = 38
# new node g = 16
#
#
# current_node coord = [1, 5]
# current_node value = 1
# current_node g = 13
# current_node h = 34
# current_node f = 47
#
#
# coord = [2, 5]
# value = 2
# g = 1
# h = 33
# f = 34
# new node g = 14
#
#
# coord = [1, 6]
# value = 7
# g = 6
# h = 33
# f = 39
# new node g = 19
#
#
# current_node coord = [2, 0]
# current_node value = 1
# current_node g = 9
# current_node h = 38
# current_node f = 47
#
#
# coord = [3, 0]
# value = 9
# g = 8
# h = 37
# f = 45
# new node g = 17
#
#
# *Faster Path* = 20
# current_node coord = [2, 4]
# current_node value = 1
# current_node g = 13
# current_node h = 34
# current_node f = 47
#
#
# coord = [3, 4]
# value = 7
# g = 6
# h = 33
# f = 39
# new node g = 19
#
#
# coord = [2, 5]
# value = 2
# g = 1
# h = 33
# f = 34
# new node g = 14
#
#
# current_node coord = [2, 5]
# current_node value = 2
# current_node g = 14
# current_node h = 33
# current_node f = 47
#
#
# coord = [3, 5]
# value = 7
# g = 5
# h = 32
# f = 37
# new node g = 19
#
#
# coord = [2, 6]
# value = 6
# g = 4
# h = 32
# f = 36
# new node g = 18
#
#
# current_node coord = [3, 8]
# current_node value = 4
# current_node g = 18
# current_node h = 29
# current_node f = 47
#
#
# coord = [2, 8]
# value = 6
# g = 2
# h = 30
# f = 32
# new node g = 20
#
#
# coord = [3, 9]
# value = 9
# g = 5
# h = 28
# f = 33
# new node g = 23
#
#
# coord = [3, 7]
# value = 4
# g = 0
# h = 30
# f = 30
# new node g = 18
#
#
# current_node coord = [6, 7]
# current_node value = 6
# current_node g = 20
# current_node h = 27
# current_node f = 47
#
#
# coord = [7, 7]
# value = 9
# g = 3
# h = 26
# f = 29
# new node g = 23
#
#
# coord = [6, 6]
# value = 0
# g = 6
# h = 28
# f = 34
# new node g = 26
#
#
# current_node coord = [6, 9]
# current_node value = 0
# current_node g = 22
# current_node h = 25
# current_node f = 47
#
#
# coord = [7, 9]
# value = 3
# g = 3
# h = 24
# f = 27
# new node g = 25
#
#
# coord = [5, 9]
# value = 0
# g = 0
# h = 26
# f = 26
# new node g = 22
#
#
# coord = [6, 10]
# value = 7
# g = 7
# h = 24
# f = 31
# new node g = 29
#
#
# current_node coord = [3, 4]
# current_node value = 7
# current_node g = 15
# current_node h = 33
# current_node f = 48
#
#
# coord = [3, 5]
# value = 7
# g = 0
# h = 32
# f = 32
# new node g = 15
#
#
# *Faster Path* = 22
# current_node coord = [3, 5]
# current_node value = 7
# current_node g = 15
# current_node h = 32
# current_node f = 47
#
#
# coord = [4, 5]
# value = 6
# g = 1
# h = 31
# f = 32
# new node g = 16
#
#
# *Faster Path* = 2
# coord = [3, 6]
# value = 5
# g = 2
# h = 31
# f = 33
# new node g = 17
#
#
# current_node coord = [4, 5]
# current_node value = 6
# current_node g = 16
# current_node h = 31
# current_node f = 47
#
#
# coord = [4, 6]
# value = 3
# g = 3
# h = 30
# f = 33
# new node g = 19
#
#
# current_node coord = [3, 6]
# current_node value = 5
# current_node g = 17
# current_node h = 31
# current_node f = 48
#
#
# coord = [4, 6]
# value = 3
# g = 2
# h = 30
# f = 32
# new node g = 19
#
#
# coord = [2, 6]
# value = 6
# g = 1
# h = 32
# f = 33
# new node g = 18
#
#
# coord = [3, 7]
# value = 4
# g = 1
# h = 30
# f = 31
# new node g = 18
#
#
# current_node coord = [3, 7]
# current_node value = 4
# current_node g = 18
# current_node h = 30
# current_node f = 48
#
#
# coord = [4, 7]
# value = 2
# g = 2
# h = 29
# f = 31
# new node g = 20
#
#
# coord = [2, 7]
# value = 1
# g = 3
# h = 31
# f = 34
# new node g = 21
#
#
# current_node coord = [5, 9]
# current_node value = 0
# current_node g = 22
# current_node h = 26
# current_node f = 48
#
#
# coord = [4, 9]
# value = 9
# g = 9
# h = 27
# f = 36
# new node g = 31
#
#
# coord = [5, 10]
# value = 4
# g = 4
# h = 25
# f = 29
# new node g = 26
#
#
# current_node coord = [4, 3]
# current_node value = 8
# current_node g = 16
# current_node h = 33
# current_node f = 49
#
#
# current_node coord = [4, 6]
# current_node value = 3
# current_node g = 19
# current_node h = 30
# current_node f = 49
#
#
# coord = [4, 7]
# value = 2
# g = 1
# h = 29
# f = 30
# new node g = 20
#
#
# current_node coord = [4, 7]
# current_node value = 2
# current_node g = 20
# current_node h = 29
# current_node f = 49
#
#
# current_node coord = [5, 1]
# current_node value = 5
# current_node g = 15
# current_node h = 34
# current_node f = 49
#
#
# coord = [6, 1]
# value = 4
# g = 1
# h = 33
# f = 34
# new node g = 16
#
#
# *Faster Path* = 8
# coord = [4, 1]
# value = 9
# g = 4
# h = 35
# f = 39
# new node g = 19
#
#
# coord = [5, 0]
# value = 5
# g = 0
# h = 35
# f = 35
# new node g = 15
#
#
# current_node coord = [6, 1]
# current_node value = 4
# current_node g = 16
# current_node h = 33
# current_node f = 49
#
#
# coord = [7, 1]
# value = 2
# g = 2
# h = 32
# f = 34
# new node g = 18
#
#
# coord = [6, 0]
# value = 0
# g = 4
# h = 34
# f = 38
# new node g = 20
#
#
# current_node coord = [6, 3]
# current_node value = 8
# current_node g = 18
# current_node h = 31
# current_node f = 49
#
#
# coord = [7, 3]
# value = 8
# g = 0
# h = 30
# f = 30
# new node g = 18
#
#
# current_node coord = [7, 3]
# current_node value = 8
# current_node g = 18
# current_node h = 30
# current_node f = 48
#
#
# coord = [8, 3]
# value = 1
# g = 7
# h = 29
# f = 36
# new node g = 25
#
#
# coord = [7, 4]
# value = 8
# g = 0
# h = 29
# f = 29
# new node g = 18
#
#
# *Faster Path* = 1
# coord = [7, 2]
# value = 4
# g = 4
# h = 31
# f = 35
# new node g = 22
#
#
# current_node coord = [7, 4]
# current_node value = 8
# current_node g = 18
# current_node h = 29
# current_node f = 47
#
#
# coord = [8, 4]
# value = 8
# g = 0
# h = 28
# f = 28
# new node g = 18
#
#
# coord = [7, 5]
# value = 3
# g = 5
# h = 28
# f = 33
# new node g = 23
#
#
# current_node coord = [8, 4]
# current_node value = 8
# current_node g = 18
# current_node h = 28
# current_node f = 46
#
#
# coord = [9, 4]
# value = 2
# g = 6
# h = 27
# f = 33
# new node g = 24
#
#
# coord = [8, 5]
# value = 7
# g = 1
# h = 27
# f = 28
# new node g = 19
#
#
# coord = [8, 3]
# value = 1
# g = 7
# h = 29
# f = 36
# new node g = 25
#
#
# current_node coord = [8, 5]
# current_node value = 7
# current_node g = 19
# current_node h = 27
# current_node f = 46
#
#
# coord = [9, 5]
# value = 4
# g = 3
# h = 26
# f = 29
# new node g = 22
#
#
# coord = [7, 5]
# value = 3
# g = 4
# h = 28
# f = 32
# new node g = 23
#
#
# coord = [8, 6]
# value = 9
# g = 2
# h = 26
# f = 28
# new node g = 21
#
#
# current_node coord = [8, 6]
# current_node value = 9
# current_node g = 21
# current_node h = 26
# current_node f = 47
#
#
# coord = [9, 6]
# value = 3
# g = 6
# h = 25
# f = 31
# new node g = 27
#
#
# coord = [7, 6]
# value = 0
# g = 9
# h = 27
# f = 36
# new node g = 30
#
#
# coord = [8, 7]
# value = 3
# g = 6
# h = 25
# f = 31
# new node g = 27
#
#
# current_node coord = [9, 5]
# current_node value = 4
# current_node g = 22
# current_node h = 26
# current_node f = 48
#
#
# coord = [10, 5]
# value = 0
# g = 4
# h = 25
# f = 29
# new node g = 26
#
#
# coord = [9, 6]
# value = 3
# g = 1
# h = 25
# f = 26
# new node g = 23
#
#
# *Faster Path* = 24
# coord = [9, 4]
# value = 2
# g = 2
# h = 27
# f = 29
# new node g = 24
#
#
# current_node coord = [9, 6]
# current_node value = 3
# current_node g = 23
# current_node h = 25
# current_node f = 48
#
#
# coord = [10, 6]
# value = 8
# g = 5
# h = 24
# f = 29
# new node g = 28
#
#
# coord = [9, 7]
# value = 9
# g = 6
# h = 24
# f = 30
# new node g = 29
#
#
# current_node coord = [7, 2]
# current_node value = 4
# current_node g = 18
# current_node h = 31
# current_node f = 49
#
#
# coord = [8, 2]
# value = 3
# g = 1
# h = 30
# f = 31
# new node g = 19
#
#
# coord = [7, 1]
# value = 2
# g = 2
# h = 32
# f = 34
# new node g = 20
#
#
# current_node coord = [7, 7]
# current_node value = 9
# current_node g = 23
# current_node h = 26
# current_node f = 49
#
#
# coord = [8, 7]
# value = 3
# g = 6
# h = 25
# f = 31
# new node g = 29
#
#
# coord = [7, 8]
# value = 8
# g = 1
# h = 25
# f = 26
# new node g = 24
#
#
# *Faster Path* = 17
# coord = [7, 6]
# value = 0
# g = 9
# h = 27
# f = 36
# new node g = 32
#
#
# current_node coord = [7, 8]
# current_node value = 8
# current_node g = 24
# current_node h = 25
# current_node f = 49
#
#
# coord = [8, 8]
# value = 2
# g = 6
# h = 24
# f = 30
# new node g = 30
#
#
# coord = [7, 9]
# value = 3
# g = 5
# h = 24
# f = 29
# new node g = 29
#
#
# current_node coord = [7, 9]
# current_node value = 3
# current_node g = 25
# current_node h = 24
# current_node f = 49
#
#
# coord = [8, 9]
# value = 2
# g = 1
# h = 23
# f = 24
# new node g = 26
#
#
# coord = [7, 10]
# value = 7
# g = 4
# h = 23
# f = 27
# new node g = 29
#
#
# current_node coord = [8, 2]
# current_node value = 3
# current_node g = 19
# current_node h = 30
# current_node f = 49
#
#
# coord = [9, 2]
# value = 3
# g = 0
# h = 29
# f = 29
# new node g = 19
#
#
# coord = [8, 3]
# value = 1
# g = 2
# h = 29
# f = 31
# new node g = 21
#
#
# *Faster Path* = 20
# coord = [8, 1]
# value = 3
# g = 0
# h = 31
# f = 31
# new node g = 19
#
#
# current_node coord = [9, 2]
# current_node value = 3
# current_node g = 19
# current_node h = 29
# current_node f = 48
#
#
# coord = [10, 2]
# value = 9
# g = 6
# h = 28
# f = 34
# new node g = 25
#
#
# coord = [9, 3]
# value = 7
# g = 4
# h = 28
# f = 32
# new node g = 23
#
#
# coord = [9, 1]
# value = 4
# g = 1
# h = 30
# f = 31
# new node g = 20
#
#
# current_node coord = [8, 9]
# current_node value = 2
# current_node g = 26
# current_node h = 23
# current_node f = 49
#
#
# coord = [9, 9]
# value = 7
# g = 5
# h = 22
# f = 27
# new node g = 31
#
#
# coord = [8, 10]
# value = 9
# g = 7
# h = 22
# f = 29
# new node g = 33
#
#
# coord = [8, 8]
# value = 2
# g = 0
# h = 24
# f = 24
# new node g = 26
#
#
# *Faster Path* = 26
# current_node coord = [0, 6]
# current_node value = 8
# current_node g = 16
# current_node h = 34
# current_node f = 50
#
#
# coord = [1, 6]
# value = 7
# g = 1
# h = 33
# f = 34
# new node g = 17
#
#
# *Faster Path* = 15
# coord = [0, 7]
# value = 2
# g = 6
# h = 33
# f = 39
# new node g = 22
#
#
# current_node coord = [1, 6]
# current_node value = 7
# current_node g = 17
# current_node h = 33
# current_node f = 50
#
#
# coord = [2, 6]
# value = 6
# g = 1
# h = 32
# f = 33
# new node g = 18
#
#
# coord = [1, 7]
# value = 6
# g = 1
# h = 32
# f = 33
# new node g = 18
#
#
# current_node coord = [1, 7]
# current_node value = 6
# current_node g = 18
# current_node h = 32
# current_node f = 50
#
#
# coord = [2, 7]
# value = 1
# g = 5
# h = 31
# f = 36
# new node g = 23
#
#
# coord = [0, 7]
# value = 2
# g = 4
# h = 33
# f = 37
# new node g = 22
#
#
# coord = [1, 8]
# value = 9
# g = 3
# h = 31
# f = 34
# new node g = 21
#
#
# current_node coord = [2, 6]
# current_node value = 6
# current_node g = 18
# current_node h = 32
# current_node f = 50
#
#
# coord = [2, 7]
# value = 1
# g = 5
# h = 31
# f = 36
# new node g = 23
#
#
# current_node coord = [2, 8]
# current_node value = 6
# current_node g = 20
# current_node h = 30
# current_node f = 50
#
#
# coord = [1, 8]
# value = 9
# g = 3
# h = 31
# f = 34
# new node g = 23
#
#
# coord = [2, 9]
# value = 9
# g = 3
# h = 29
# f = 32
# new node g = 23
#
#
# coord = [2, 7]
# value = 1
# g = 5
# h = 31
# f = 36
# new node g = 25
#
#
# current_node coord = [4, 9]
# current_node value = 9
# current_node g = 23
# current_node h = 27
# current_node f = 50
#
#
# coord = [3, 9]
# value = 9
# g = 0
# h = 28
# f = 28
# new node g = 23
#
#
# coord = [4, 10]
# value = 8
# g = 1
# h = 26
# f = 27
# new node g = 24
#
#
# current_node coord = [4, 10]
# current_node value = 8
# current_node g = 24
# current_node h = 26
# current_node f = 50
#
#
# coord = [5, 10]
# value = 4
# g = 4
# h = 25
# f = 29
# new node g = 28
#
#
# coord = [3, 10]
# value = 8
# g = 0
# h = 27
# f = 27
# new node g = 24
#
#
# coord = [4, 11]
# value = 7
# g = 1
# h = 25
# f = 26
# new node g = 25
#
#
# current_node coord = [4, 11]
# current_node value = 7
# current_node g = 25
# current_node h = 25
# current_node f = 50
#
#
# coord = [5, 11]
# value = 6
# g = 1
# h = 24
# f = 25
# new node g = 26
#
#
# coord = [3, 11]
# value = 7
# g = 0
# h = 26
# f = 26
# new node g = 25
#
#
# coord = [4, 12]
# value = 4
# g = 3
# h = 24
# f = 27
# new node g = 28
#
#
# current_node coord = [5, 0]
# current_node value = 5
# current_node g = 15
# current_node h = 35
# current_node f = 50
#
#
# coord = [6, 0]
# value = 0
# g = 5
# h = 34
# f = 39
# new node g = 20
#
#
# coord = [4, 0]
# value = 9
# g = 4
# h = 36
# f = 40
# new node g = 19
#
#
# current_node coord = [5, 11]
# current_node value = 6
# current_node g = 26
# current_node h = 24
# current_node f = 50
#
#
# coord = [6, 11]
# value = 3
# g = 3
# h = 23
# f = 26
# new node g = 29
#
#
# coord = [5, 12]
# value = 8
# g = 2
# h = 23
# f = 25
# new node g = 28
#
#
# coord = [5, 10]
# value = 4
# g = 2
# h = 25
# f = 27
# new node g = 28
#
#
# current_node coord = [6, 5]
# current_node value = 9
# current_node g = 21
# current_node h = 29
# current_node f = 50
#
#
# coord = [7, 5]
# value = 3
# g = 6
# h = 28
# f = 34
# new node g = 27
#
#
# coord = [6, 6]
# value = 0
# g = 9
# h = 28
# f = 37
# new node g = 30
#
#
# current_node coord = [6, 6]
# current_node value = 0
# current_node g = 22
# current_node h = 28
# current_node f = 50
#
#
# coord = [7, 6]
# value = 0
# g = 0
# h = 27
# f = 27
# new node g = 22
#
#
# *Faster Path* = 25
# current_node coord = [7, 6]
# current_node value = 0
# current_node g = 22
# current_node h = 27
# current_node f = 49
#
#
# coord = [7, 5]
# value = 3
# g = 3
# h = 28
# f = 31
# new node g = 25
#
#
# current_node coord = [7, 1]
# current_node value = 2
# current_node g = 18
# current_node h = 32
# current_node f = 50
#
#
# coord = [8, 1]
# value = 3
# g = 1
# h = 31
# f = 32
# new node g = 19
#
#
# coord = [7, 0]
# value = 4
# g = 2
# h = 33
# f = 35
# new node g = 20
#
#
# current_node coord = [8, 1]
# current_node value = 3
# current_node g = 19
# current_node h = 31
# current_node f = 50
#
#
# coord = [9, 1]
# value = 4
# g = 1
# h = 30
# f = 31
# new node g = 20
#
#
# coord = [8, 0]
# value = 9
# g = 6
# h = 32
# f = 38
# new node g = 25
#
#
# current_node coord = [8, 3]
# current_node value = 1
# current_node g = 21
# current_node h = 29
# current_node f = 50
#
#
# coord = [9, 3]
# value = 7
# g = 6
# h = 28
# f = 34
# new node g = 27
#
#
# current_node coord = [8, 8]
# current_node value = 2
# current_node g = 26
# current_node h = 24
# current_node f = 50
#
#
# coord = [9, 8]
# value = 0
# g = 2
# h = 23
# f = 25
# new node g = 28
#
#
# coord = [8, 7]
# value = 3
# g = 1
# h = 25
# f = 26
# new node g = 27
#
#
# current_node coord = [9, 1]
# current_node value = 4
# current_node g = 20
# current_node h = 30
# current_node f = 50
#
#
# coord = [10, 1]
# value = 4
# g = 0
# h = 29
# f = 29
# new node g = 20
#
#
# coord = [9, 0]
# value = 0
# g = 4
# h = 31
# f = 35
# new node g = 24
#
#
# current_node coord = [10, 1]
# current_node value = 4
# current_node g = 20
# current_node h = 29
# current_node f = 49
#
#
# coord = [11, 1]
# value = 8
# g = 4
# h = 28
# f = 32
# new node g = 24
#
#
# coord = [10, 2]
# value = 9
# g = 5
# h = 28
# f = 33
# new node g = 25
#
#
# coord = [10, 0]
# value = 4
# g = 0
# h = 30
# f = 30
# new node g = 20
#
#
# current_node coord = [10, 0]
# current_node value = 4
# current_node g = 20
# current_node h = 30
# current_node f = 50
#
#
# coord = [11, 0]
# value = 9
# g = 5
# h = 29
# f = 34
# new node g = 25
#
#
# coord = [9, 0]
# value = 0
# g = 4
# h = 31
# f = 35
# new node g = 24
#
#
# current_node coord = [3, 9]
# current_node value = 9
# current_node g = 23
# current_node h = 28
# current_node f = 51
#
#
# coord = [2, 9]
# value = 9
# g = 0
# h = 29
# f = 29
# new node g = 23
#
#
# coord = [3, 10]
# value = 8
# g = 1
# h = 27
# f = 28
# new node g = 24
#
#
# current_node coord = [3, 10]
# current_node value = 8
# current_node g = 24
# current_node h = 27
# current_node f = 51
#
#
# coord = [2, 10]
# value = 2
# g = 6
# h = 28
# f = 34
# new node g = 30
#
#
# coord = [3, 11]
# value = 7
# g = 1
# h = 26
# f = 27
# new node g = 25
#
#
# current_node coord = [3, 11]
# current_node value = 7
# current_node g = 25
# current_node h = 26
# current_node f = 51
#
#
# coord = [2, 11]
# value = 2
# g = 5
# h = 27
# f = 32
# new node g = 30
#
#
# coord = [3, 12]
# value = 1
# g = 6
# h = 25
# f = 31
# new node g = 31
#
#
# current_node coord = [5, 10]
# current_node value = 4
# current_node g = 26
# current_node h = 25
# current_node f = 51
#
#
# coord = [6, 10]
# value = 7
# g = 3
# h = 24
# f = 27
# new node g = 29
#
#
# current_node coord = [5, 12]
# current_node value = 8
# current_node g = 28
# current_node h = 23
# current_node f = 51
#
#
# coord = [6, 12]
# value = 0
# g = 8
# h = 22
# f = 30
# new node g = 36
#
#
# coord = [4, 12]
# value = 4
# g = 4
# h = 24
# f = 28
# new node g = 32
#
#
# coord = [5, 13]
# value = 9
# g = 1
# h = 22
# f = 23
# new node g = 29
#
#
# current_node coord = [5, 13]
# current_node value = 9
# current_node g = 29
# current_node h = 22
# current_node f = 51
#
#
# coord = [6, 13]
# value = 1
# g = 8
# h = 21
# f = 29
# new node g = 37
#
#
# coord = [4, 13]
# value = 8
# g = 1
# h = 23
# f = 24
# new node g = 30
#
#
# coord = [5, 14]
# value = 7
# g = 2
# h = 21
# f = 23
# new node g = 31
#
#
# current_node coord = [7, 5]
# current_node value = 3
# current_node g = 23
# current_node h = 28
# current_node f = 51
#
#
# current_node coord = [9, 3]
# current_node value = 7
# current_node g = 23
# current_node h = 28
# current_node f = 51
#
#
# coord = [10, 3]
# value = 4
# g = 3
# h = 27
# f = 30
# new node g = 26
#
#
# coord = [9, 4]
# value = 2
# g = 5
# h = 27
# f = 32
# new node g = 28
#
#
# current_node coord = [9, 4]
# current_node value = 2
# current_node g = 24
# current_node h = 27
# current_node f = 51
#
#
# coord = [10, 4]
# value = 0
# g = 2
# h = 26
# f = 28
# new node g = 26
#
#
# current_node coord = [9, 8]
# current_node value = 0
# current_node g = 28
# current_node h = 23
# current_node f = 51
#
#
# coord = [10, 8]
# value = 6
# g = 6
# h = 22
# f = 28
# new node g = 34
#
#
# coord = [9, 9]
# value = 7
# g = 7
# h = 22
# f = 29
# new node g = 35
#
#
# coord = [9, 7]
# value = 9
# g = 9
# h = 24
# f = 33
# new node g = 37
#
#
# current_node coord = [10, 5]
# current_node value = 0
# current_node g = 26
# current_node h = 25
# current_node f = 51
#
#
# coord = [11, 5]
# value = 5
# g = 5
# h = 24
# f = 29
# new node g = 31
#
#
# coord = [10, 6]
# value = 8
# g = 8
# h = 24
# f = 32
# new node g = 34
#
#
# coord = [10, 4]
# value = 0
# g = 0
# h = 26
# f = 26
# new node g = 26
#
#
# current_node coord = [1, 8]
# current_node value = 9
# current_node g = 21
# current_node h = 31
# current_node f = 52
#
#
# coord = [0, 8]
# value = 6
# g = 3
# h = 32
# f = 35
# new node g = 24
#
#
# coord = [1, 9]
# value = 9
# g = 0
# h = 30
# f = 30
# new node g = 21
#
#
# current_node coord = [1, 9]
# current_node value = 9
# current_node g = 21
# current_node h = 30
# current_node f = 51
#
#
# coord = [2, 9]
# value = 9
# g = 0
# h = 29
# f = 29
# new node g = 21
#
#
# *Faster Path* = 1
# coord = [0, 9]
# value = 0
# g = 9
# h = 31
# f = 40
# new node g = 30
#
#
# coord = [1, 10]
# value = 5
# g = 4
# h = 29
# f = 33
# new node g = 25
#
#
# current_node coord = [2, 9]
# current_node value = 9
# current_node g = 21
# current_node h = 29
# current_node f = 50
#
#
# coord = [2, 10]
# value = 2
# g = 7
# h = 28
# f = 35
# new node g = 28
#
#
# *Faster Path* = 21
# current_node coord = [2, 7]
# current_node value = 1
# current_node g = 21
# current_node h = 31
# current_node f = 52
#
#
# current_node coord = [4, 1]
# current_node value = 9
# current_node g = 17
# current_node h = 35
# current_node f = 52
#
#
# coord = [4, 0]
# value = 9
# g = 0
# h = 36
# f = 36
# new node g = 17
#
#
# *Faster Path* = 27
# current_node coord = [4, 12]
# current_node value = 4
# current_node g = 28
# current_node h = 24
# current_node f = 52
#
#
# coord = [3, 12]
# value = 1
# g = 3
# h = 25
# f = 28
# new node g = 31
#
#
# coord = [4, 13]
# value = 8
# g = 4
# h = 23
# f = 27
# new node g = 32
#
#
# current_node coord = [5, 14]
# current_node value = 7
# current_node g = 31
# current_node h = 21
# current_node f = 52
#
#
# coord = [6, 14]
# value = 4
# g = 3
# h = 20
# f = 23
# new node g = 34
#
#
# coord = [4, 14]
# value = 1
# g = 6
# h = 22
# f = 28
# new node g = 37
#
#
# coord = [5, 15]
# value = 9
# g = 2
# h = 20
# f = 22
# new node g = 33
#
#
# current_node coord = [6, 11]
# current_node value = 3
# current_node g = 29
# current_node h = 23
# current_node f = 52
#
#
# coord = [7, 11]
# value = 0
# g = 3
# h = 22
# f = 25
# new node g = 32
#
#
# coord = [6, 12]
# value = 0
# g = 3
# h = 22
# f = 25
# new node g = 32
#
#
# *Faster Path* = 31
# coord = [6, 10]
# value = 7
# g = 4
# h = 24
# f = 28
# new node g = 33
#
#
# current_node coord = [7, 10]
# current_node value = 7
# current_node g = 29
# current_node h = 23
# current_node f = 52
#
#
# coord = [8, 10]
# value = 9
# g = 2
# h = 22
# f = 24
# new node g = 31
#
#
# *Faster Path* = 29
# coord = [6, 10]
# value = 7
# g = 0
# h = 24
# f = 24
# new node g = 29
#
#
# coord = [7, 11]
# value = 0
# g = 7
# h = 22
# f = 29
# new node g = 36
#
#
# current_node coord = [8, 7]
# current_node value = 3
# current_node g = 27
# current_node h = 25
# current_node f = 52
#
#
# coord = [9, 7]
# value = 9
# g = 6
# h = 24
# f = 30
# new node g = 33
#
#
# current_node coord = [10, 4]
# current_node value = 0
# current_node g = 26
# current_node h = 26
# current_node f = 52
#
#
# coord = [11, 4]
# value = 2
# g = 2
# h = 25
# f = 27
# new node g = 28
#
#
# coord = [10, 3]
# value = 4
# g = 4
# h = 27
# f = 31
# new node g = 30
#
#
# current_node coord = [10, 6]
# current_node value = 8
# current_node g = 28
# current_node h = 24
# current_node f = 52
#
#
# coord = [11, 6]
# value = 8
# g = 0
# h = 23
# f = 23
# new node g = 28
#
#
# coord = [10, 7]
# value = 3
# g = 5
# h = 23
# f = 28
# new node g = 33
#
#
# current_node coord = [11, 6]
# current_node value = 8
# current_node g = 28
# current_node h = 23
# current_node f = 51
#
#
# coord = [12, 6]
# value = 3
# g = 5
# h = 22
# f = 27
# new node g = 33
#
#
# coord = [11, 7]
# value = 1
# g = 7
# h = 22
# f = 29
# new node g = 35
#
#
# coord = [11, 5]
# value = 5
# g = 3
# h = 24
# f = 27
# new node g = 31
#
#
# current_node coord = [11, 1]
# current_node value = 8
# current_node g = 24
# current_node h = 28
# current_node f = 52
#
#
# coord = [12, 1]
# value = 8
# g = 0
# h = 27
# f = 27
# new node g = 24
#
#
# coord = [11, 2]
# value = 3
# g = 5
# h = 27
# f = 32
# new node g = 29
#
#
# coord = [11, 0]
# value = 9
# g = 1
# h = 29
# f = 30
# new node g = 25
#
#
# current_node coord = [12, 1]
# current_node value = 8
# current_node g = 24
# current_node h = 27
# current_node f = 51
#
#
# coord = [13, 1]
# value = 0
# g = 8
# h = 26
# f = 34
# new node g = 32
#
#
# coord = [12, 2]
# value = 7
# g = 1
# h = 26
# f = 27
# new node g = 25
#
#
# coord = [12, 0]
# value = 4
# g = 4
# h = 28
# f = 32
# new node g = 28
#
#
# current_node coord = [12, 2]
# current_node value = 7
# current_node g = 25
# current_node h = 26
# current_node f = 51
#
#
# coord = [13, 2]
# value = 4
# g = 3
# h = 25
# f = 28
# new node g = 28
#
#
# coord = [11, 2]
# value = 3
# g = 4
# h = 27
# f = 31
# new node g = 29
#
#
# coord = [12, 3]
# value = 2
# g = 5
# h = 25
# f = 30
# new node g = 30
#
#
# current_node coord = [4, 0]
# current_node value = 9
# current_node g = 17
# current_node h = 36
# current_node f = 53
#
#
# coord = [3, 0]
# value = 9
# g = 0
# h = 37
# f = 37
# new node g = 17
#
#
# current_node coord = [4, 13]
# current_node value = 8
# current_node g = 30
# current_node h = 23
# current_node f = 53
#
#
# coord = [3, 13]
# value = 7
# g = 1
# h = 24
# f = 25
# new node g = 31
#
#
# coord = [4, 14]
# value = 1
# g = 7
# h = 22
# f = 29
# new node g = 37
#
#
# current_node coord = [5, 15]
# current_node value = 9
# current_node g = 33
# current_node h = 20
# current_node f = 53
#
#
# coord = [6, 15]
# value = 0
# g = 9
# h = 19
# f = 28
# new node g = 42
#
#
# coord = [4, 15]
# value = 5
# g = 4
# h = 21
# f = 25
# new node g = 37
#
#
# coord = [5, 16]
# value = 3
# g = 6
# h = 19
# f = 25
# new node g = 39
#
#
# current_node coord = [6, 10]
# current_node value = 7
# current_node g = 29
# current_node h = 24
# current_node f = 53
#
#
# current_node coord = [7, 0]
# current_node value = 4
# current_node g = 20
# current_node h = 33
# current_node f = 53
#
#
# coord = [8, 0]
# value = 9
# g = 5
# h = 32
# f = 37
# new node g = 25
#
#
# coord = [6, 0]
# value = 0
# g = 4
# h = 34
# f = 38
# new node g = 24
#
#
# current_node coord = [8, 10]
# current_node value = 9
# current_node g = 31
# current_node h = 22
# current_node f = 53
#
#
# coord = [9, 10]
# value = 4
# g = 5
# h = 21
# f = 26
# new node g = 36
#
#
# coord = [8, 11]
# value = 0
# g = 9
# h = 21
# f = 30
# new node g = 40
#
#
# current_node coord = [9, 7]
# current_node value = 9
# current_node g = 29
# current_node h = 24
# current_node f = 53
#
#
# coord = [10, 7]
# value = 3
# g = 6
# h = 23
# f = 29
# new node g = 35
#
#
# current_node coord = [9, 9]
# current_node value = 7
# current_node g = 31
# current_node h = 22
# current_node f = 53
#
#
# coord = [10, 9]
# value = 2
# g = 5
# h = 21
# f = 26
# new node g = 36
#
#
# coord = [9, 10]
# value = 4
# g = 3
# h = 21
# f = 24
# new node g = 34
#
#
# *Faster Path* = 26
# current_node coord = [10, 2]
# current_node value = 9
# current_node g = 25
# current_node h = 28
# current_node f = 53
#
#
# coord = [11, 2]
# value = 3
# g = 6
# h = 27
# f = 33
# new node g = 31
#
#
# coord = [10, 3]
# value = 4
# g = 5
# h = 27
# f = 32
# new node g = 30
#
#
# current_node coord = [10, 3]
# current_node value = 4
# current_node g = 26
# current_node h = 27
# current_node f = 53
#
#
# coord = [11, 3]
# value = 1
# g = 3
# h = 26
# f = 29
# new node g = 29
#
#
# current_node coord = [11, 4]
# current_node value = 2
# current_node g = 28
# current_node h = 25
# current_node f = 53
#
#
# coord = [12, 4]
# value = 0
# g = 2
# h = 24
# f = 26
# new node g = 30
#
#
# coord = [11, 5]
# value = 5
# g = 3
# h = 24
# f = 27
# new node g = 31
#
#
# coord = [11, 3]
# value = 1
# g = 1
# h = 26
# f = 27
# new node g = 29
#
#
# current_node coord = [13, 2]
# current_node value = 4
# current_node g = 28
# current_node h = 25
# current_node f = 53
#
#
# coord = [14, 2]
# value = 1
# g = 3
# h = 24
# f = 27
# new node g = 31
#
#
# coord = [13, 3]
# value = 7
# g = 3
# h = 24
# f = 27
# new node g = 31
#
#
# coord = [13, 1]
# value = 0
# g = 4
# h = 26
# f = 30
# new node g = 32
#
#
# current_node coord = [1, 10]
# current_node value = 5
# current_node g = 25
# current_node h = 29
# current_node f = 54
#
#
# coord = [2, 10]
# value = 2
# g = 3
# h = 28
# f = 31
# new node g = 28
#
#
# coord = [0, 10]
# value = 6
# g = 1
# h = 30
# f = 31
# new node g = 26
#
#
# coord = [1, 11]
# value = 7
# g = 2
# h = 28
# f = 30
# new node g = 27
#
#
# current_node coord = [3, 0]
# current_node value = 9
# current_node g = 17
# current_node h = 37
# current_node f = 54
#
#
# current_node coord = [6, 0]
# current_node value = 0
# current_node g = 20
# current_node h = 34
# current_node f = 54
#
#
# current_node coord = [6, 12]
# current_node value = 0
# current_node g = 32
# current_node h = 22
# current_node f = 54
#
#
# coord = [7, 12]
# value = 9
# g = 9
# h = 21
# f = 30
# new node g = 41
#
#
# coord = [6, 13]
# value = 1
# g = 1
# h = 21
# f = 22
# new node g = 33
#
#
# *Faster Path* = 21
# current_node coord = [6, 13]
# current_node value = 1
# current_node g = 33
# current_node h = 21
# current_node f = 54
#
#
# coord = [7, 13]
# value = 1
# g = 0
# h = 20
# f = 20
# new node g = 33
#
#
# coord = [6, 14]
# value = 4
# g = 3
# h = 20
# f = 23
# new node g = 36
#
#
# current_node coord = [7, 13]
# current_node value = 1
# current_node g = 33
# current_node h = 20
# current_node f = 53
#
#
# coord = [8, 13]
# value = 0
# g = 1
# h = 19
# f = 20
# new node g = 34
#
#
# coord = [7, 14]
# value = 4
# g = 3
# h = 19
# f = 22
# new node g = 36
#
#
# coord = [7, 12]
# value = 9
# g = 8
# h = 21
# f = 29
# new node g = 41
#
#
# current_node coord = [8, 13]
# current_node value = 0
# current_node g = 34
# current_node h = 19
# current_node f = 53
#
#
# coord = [9, 13]
# value = 1
# g = 1
# h = 18
# f = 19
# new node g = 35
#
#
# coord = [8, 14]
# value = 6
# g = 6
# h = 18
# f = 24
# new node g = 40
#
#
# coord = [8, 12]
# value = 5
# g = 5
# h = 20
# f = 25
# new node g = 39
#
#
# current_node coord = [9, 13]
# current_node value = 1
# current_node g = 35
# current_node h = 18
# current_node f = 53
#
#
# coord = [10, 13]
# value = 1
# g = 0
# h = 17
# f = 17
# new node g = 35
#
#
# coord = [9, 14]
# value = 1
# g = 0
# h = 17
# f = 17
# new node g = 35
#
#
# coord = [9, 12]
# value = 9
# g = 8
# h = 19
# f = 27
# new node g = 43
#
#
# current_node coord = [9, 14]
# current_node value = 1
# current_node g = 35
# current_node h = 17
# current_node f = 52
#
#
# coord = [10, 14]
# value = 0
# g = 1
# h = 16
# f = 17
# new node g = 36
#
#
# coord = [8, 14]
# value = 6
# g = 5
# h = 18
# f = 23
# new node g = 40
#
#
# coord = [9, 15]
# value = 9
# g = 8
# h = 16
# f = 24
# new node g = 43
#
#
# current_node coord = [10, 13]
# current_node value = 1
# current_node g = 35
# current_node h = 17
# current_node f = 52
#
#
# coord = [11, 13]
# value = 8
# g = 7
# h = 16
# f = 23
# new node g = 42
#
#
# coord = [10, 14]
# value = 0
# g = 1
# h = 16
# f = 17
# new node g = 36
#
#
# coord = [10, 12]
# value = 9
# g = 8
# h = 18
# f = 26
# new node g = 43
#
#
# current_node coord = [10, 14]
# current_node value = 0
# current_node g = 36
# current_node h = 16
# current_node f = 52
#
#
# coord = [11, 14]
# value = 6
# g = 6
# h = 15
# f = 21
# new node g = 42
#
#
# coord = [10, 15]
# value = 8
# g = 8
# h = 15
# f = 23
# new node g = 44
#
#
# current_node coord = [6, 14]
# current_node value = 4
# current_node g = 34
# current_node h = 20
# current_node f = 54
#
#
# coord = [7, 14]
# value = 4
# g = 0
# h = 19
# f = 19
# new node g = 34
#
#
# *Faster Path* = 8
# coord = [6, 15]
# value = 0
# g = 4
# h = 19
# f = 23
# new node g = 38
#
#
# *Faster Path* = 28
# current_node coord = [7, 14]
# current_node value = 4
# current_node g = 34
# current_node h = 19
# current_node f = 53
#
#
# coord = [8, 14]
# value = 6
# g = 2
# h = 18
# f = 20
# new node g = 36
#
#
# *Faster Path* = 37
# coord = [7, 15]
# value = 3
# g = 1
# h = 18
# f = 19
# new node g = 35
#
#
# current_node coord = [7, 15]
# current_node value = 3
# current_node g = 35
# current_node h = 18
# current_node f = 53
#
#
# coord = [8, 15]
# value = 1
# g = 2
# h = 17
# f = 19
# new node g = 37
#
#
# coord = [6, 15]
# value = 0
# g = 3
# h = 19
# f = 22
# new node g = 38
#
#
# coord = [7, 16]
# value = 9
# g = 6
# h = 17
# f = 23
# new node g = 41
#
#
# current_node coord = [7, 11]
# current_node value = 0
# current_node g = 32
# current_node h = 22
# current_node f = 54
#
#
# coord = [8, 11]
# value = 0
# g = 0
# h = 21
# f = 21
# new node g = 32
#
#
# *Faster Path* = 30
# coord = [7, 12]
# value = 9
# g = 9
# h = 21
# f = 30
# new node g = 41
#
#
# current_node coord = [8, 11]
# current_node value = 0
# current_node g = 32
# current_node h = 21
# current_node f = 53
#
#
# coord = [9, 11]
# value = 1
# g = 1
# h = 20
# f = 21
# new node g = 33
#
#
# coord = [8, 12]
# value = 5
# g = 5
# h = 20
# f = 25
# new node g = 37
#
#
# *Faster Path* = 36
# current_node coord = [9, 11]
# current_node value = 1
# current_node g = 33
# current_node h = 20
# current_node f = 53
#
#
# coord = [10, 11]
# value = 0
# g = 1
# h = 19
# f = 20
# new node g = 34
#
#
# coord = [9, 12]
# value = 9
# g = 8
# h = 19
# f = 27
# new node g = 41
#
#
# *Faster Path* = 39
# coord = [9, 10]
# value = 4
# g = 3
# h = 21
# f = 24
# new node g = 36
#
#
# current_node coord = [10, 11]
# current_node value = 0
# current_node g = 34
# current_node h = 19
# current_node f = 53
#
#
# coord = [11, 11]
# value = 5
# g = 5
# h = 18
# f = 23
# new node g = 39
#
#
# coord = [10, 12]
# value = 9
# g = 9
# h = 18
# f = 27
# new node g = 43
#
#
# coord = [10, 10]
# value = 0
# g = 0
# h = 20
# f = 20
# new node g = 34
#
#
# current_node coord = [8, 14]
# current_node value = 6
# current_node g = 36
# current_node h = 18
# current_node f = 54
#
#
# coord = [8, 15]
# value = 1
# g = 5
# h = 17
# f = 22
# new node g = 41
#
#
# current_node coord = [8, 15]
# current_node value = 1
# current_node g = 37
# current_node h = 17
# current_node f = 54
#
#
# coord = [9, 15]
# value = 9
# g = 8
# h = 16
# f = 24
# new node g = 45
#
#
# coord = [8, 16]
# value = 6
# g = 5
# h = 16
# f = 21
# new node g = 42
#
#
# current_node coord = [10, 10]
# current_node value = 0
# current_node g = 34
# current_node h = 20
# current_node f = 54
#
#
# coord = [11, 10]
# value = 7
# g = 7
# h = 19
# f = 26
# new node g = 41
#
#
# coord = [9, 10]
# value = 4
# g = 4
# h = 21
# f = 25
# new node g = 38
#
#
# coord = [10, 9]
# value = 2
# g = 2
# h = 21
# f = 23
# new node g = 36
#
#
# current_node coord = [11, 0]
# current_node value = 9
# current_node g = 25
# current_node h = 29
# current_node f = 54
#
#
# coord = [12, 0]
# value = 4
# g = 5
# h = 28
# f = 33
# new node g = 30
#
#
# current_node coord = [12, 4]
# current_node value = 0
# current_node g = 30
# current_node h = 24
# current_node f = 54
#
#
# coord = [13, 4]
# value = 4
# g = 4
# h = 23
# f = 27
# new node g = 34
#
#
# coord = [12, 5]
# value = 0
# g = 0
# h = 23
# f = 23
# new node g = 30
#
#
# coord = [12, 3]
# value = 2
# g = 2
# h = 25
# f = 27
# new node g = 32
#
#
# current_node coord = [12, 5]
# current_node value = 0
# current_node g = 30
# current_node h = 23
# current_node f = 53
#
#
# coord = [13, 5]
# value = 6
# g = 6
# h = 22
# f = 28
# new node g = 36
#
#
# coord = [11, 5]
# value = 5
# g = 5
# h = 24
# f = 29
# new node g = 35
#
#
# coord = [12, 6]
# value = 3
# g = 3
# h = 22
# f = 25
# new node g = 33
#
#
# current_node coord = [0, 7]
# current_node value = 2
# current_node g = 22
# current_node h = 33
# current_node f = 55
#
#
# coord = [0, 8]
# value = 6
# g = 4
# h = 32
# f = 36
# new node g = 26
#
#
# current_node coord = [1, 11]
# current_node value = 7
# current_node g = 27
# current_node h = 28
# current_node f = 55
#
#
# coord = [2, 11]
# value = 2
# g = 5
# h = 27
# f = 32
# new node g = 32
#
#
# coord = [0, 11]
# value = 7
# g = 0
# h = 29
# f = 29
# new node g = 27
#
#
# coord = [1, 12]
# value = 8
# g = 1
# h = 27
# f = 28
# new node g = 28
#
#
# current_node coord = [1, 12]
# current_node value = 8
# current_node g = 28
# current_node h = 27
# current_node f = 55
#
#
# coord = [2, 12]
# value = 3
# g = 5
# h = 26
# f = 31
# new node g = 33
#
#
# coord = [0, 12]
# value = 5
# g = 3
# h = 28
# f = 31
# new node g = 31
#
#
# coord = [1, 13]
# value = 0
# g = 8
# h = 26
# f = 34
# new node g = 36
#
#
# current_node coord = [3, 13]
# current_node value = 7
# current_node g = 31
# current_node h = 24
# current_node f = 55
#
#
# coord = [2, 13]
# value = 3
# g = 4
# h = 25
# f = 29
# new node g = 35
#
#
# coord = [3, 14]
# value = 1
# g = 6
# h = 23
# f = 29
# new node g = 37
#
#
# coord = [3, 12]
# value = 1
# g = 6
# h = 25
# f = 31
# new node g = 37
#
#
# current_node coord = [9, 0]
# current_node value = 0
# current_node g = 24
# current_node h = 31
# current_node f = 55
#
#
# coord = [8, 0]
# value = 9
# g = 9
# h = 32
# f = 41
# new node g = 33
#
#
# current_node coord = [9, 10]
# current_node value = 4
# current_node g = 34
# current_node h = 21
# current_node f = 55
#
#
# current_node coord = [11, 3]
# current_node value = 1
# current_node g = 29
# current_node h = 26
# current_node f = 55
#
#
# coord = [12, 3]
# value = 2
# g = 1
# h = 25
# f = 26
# new node g = 30
#
#
# coord = [11, 2]
# value = 3
# g = 2
# h = 27
# f = 29
# new node g = 31
#
#
# current_node coord = [11, 5]
# current_node value = 5
# current_node g = 31
# current_node h = 24
# current_node f = 55
#
#
# current_node coord = [12, 3]
# current_node value = 2
# current_node g = 30
# current_node h = 25
# current_node f = 55
#
#
# coord = [13, 3]
# value = 7
# g = 5
# h = 24
# f = 29
# new node g = 35
#
#
# current_node coord = [12, 6]
# current_node value = 3
# current_node g = 33
# current_node h = 22
# current_node f = 55
#
#
# coord = [13, 6]
# value = 3
# g = 0
# h = 21
# f = 21
# new node g = 33
#
#
# coord = [12, 7]
# value = 6
# g = 3
# h = 21
# f = 24
# new node g = 36
#
#
# current_node coord = [13, 6]
# current_node value = 3
# current_node g = 33
# current_node h = 21
# current_node f = 54
#
#
# coord = [14, 6]
# value = 7
# g = 4
# h = 20
# f = 24
# new node g = 37
#
#
# coord = [13, 7]
# value = 1
# g = 2
# h = 20
# f = 22
# new node g = 35
#
#
# coord = [13, 5]
# value = 6
# g = 3
# h = 22
# f = 25
# new node g = 36
#
#
# current_node coord = [13, 3]
# current_node value = 7
# current_node g = 31
# current_node h = 24
# current_node f = 55
#
#
# coord = [14, 3]
# value = 2
# g = 5
# h = 23
# f = 28
# new node g = 36
#
#
# coord = [13, 4]
# value = 4
# g = 3
# h = 23
# f = 26
# new node g = 34
#
#
# current_node coord = [13, 7]
# current_node value = 1
# current_node g = 35
# current_node h = 20
# current_node f = 55
#
#
# coord = [14, 7]
# value = 9
# g = 8
# h = 19
# f = 27
# new node g = 43
#
#
# coord = [12, 7]
# value = 6
# g = 5
# h = 21
# f = 26
# new node g = 40
#
#
# coord = [13, 8]
# value = 2
# g = 1
# h = 19
# f = 20
# new node g = 36
#
#
# current_node coord = [13, 8]
# current_node value = 2
# current_node g = 36
# current_node h = 19
# current_node f = 55
#
#
# coord = [14, 8]
# value = 3
# g = 1
# h = 18
# f = 19
# new node g = 37
#
#
# coord = [12, 8]
# value = 2
# g = 0
# h = 20
# f = 20
# new node g = 36
#
#
# coord = [13, 9]
# value = 0
# g = 2
# h = 18
# f = 20
# new node g = 38
#
#
# current_node coord = [14, 2]
# current_node value = 1
# current_node g = 31
# current_node h = 24
# current_node f = 55
#
#
# coord = [15, 2]
# value = 7
# g = 6
# h = 23
# f = 29
# new node g = 37
#
#
# coord = [14, 3]
# value = 2
# g = 1
# h = 23
# f = 24
# new node g = 32
#
#
# *Faster Path* = 33
# coord = [14, 1]
# value = 4
# g = 3
# h = 25
# f = 28
# new node g = 34
#
#
# current_node coord = [14, 3]
# current_node value = 2
# current_node g = 32
# current_node h = 23
# current_node f = 55
#
#
# coord = [15, 3]
# value = 0
# g = 2
# h = 22
# f = 24
# new node g = 34
#
#
# coord = [14, 4]
# value = 0
# g = 2
# h = 22
# f = 24
# new node g = 34
#
#
# current_node coord = [14, 8]
# current_node value = 3
# current_node g = 37
# current_node h = 18
# current_node f = 55
#
#
# coord = [15, 8]
# value = 2
# g = 1
# h = 17
# f = 18
# new node g = 38
#
#
# coord = [14, 9]
# value = 5
# g = 2
# h = 17
# f = 19
# new node g = 39
#
#
# coord = [14, 7]
# value = 9
# g = 6
# h = 19
# f = 25
# new node g = 43
#
#
# current_node coord = [15, 8]
# current_node value = 2
# current_node g = 38
# current_node h = 17
# current_node f = 55
#
#
# coord = [16, 8]
# value = 9
# g = 7
# h = 16
# f = 23
# new node g = 45
#
#
# coord = [15, 9]
# value = 6
# g = 4
# h = 16
# f = 20
# new node g = 42
#
#
# coord = [15, 7]
# value = 7
# g = 5
# h = 18
# f = 23
# new node g = 43
#
#
# current_node coord = [0, 8]
# current_node value = 6
# current_node g = 24
# current_node h = 32
# current_node f = 56
#
#
# coord = [0, 9]
# value = 0
# g = 6
# h = 31
# f = 37
# new node g = 30
#
#
# current_node coord = [0, 10]
# current_node value = 6
# current_node g = 26
# current_node h = 30
# current_node f = 56
#
#
# coord = [0, 11]
# value = 7
# g = 1
# h = 29
# f = 30
# new node g = 27
#
#
# coord = [0, 9]
# value = 0
# g = 6
# h = 31
# f = 37
# new node g = 32
#
#
# current_node coord = [0, 11]
# current_node value = 7
# current_node g = 27
# current_node h = 29
# current_node f = 56
#
#
# coord = [0, 12]
# value = 5
# g = 2
# h = 28
# f = 30
# new node g = 29
#
#
# *Faster Path* = 40
# current_node coord = [2, 10]
# current_node value = 2
# current_node g = 28
# current_node h = 28
# current_node f = 56
#
#
# coord = [2, 11]
# value = 2
# g = 0
# h = 27
# f = 27
# new node g = 28
#
#
# *Faster Path* = 19
# current_node coord = [2, 11]
# current_node value = 2
# current_node g = 28
# current_node h = 27
# current_node f = 55
#
#
# coord = [2, 12]
# value = 3
# g = 1
# h = 26
# f = 27
# new node g = 29
#
#
# *Faster Path* = 32
# current_node coord = [2, 12]
# current_node value = 3
# current_node g = 29
# current_node h = 26
# current_node f = 55
#
#
# coord = [3, 12]
# value = 1
# g = 2
# h = 25
# f = 27
# new node g = 31
#
#
# coord = [2, 13]
# value = 3
# g = 0
# h = 25
# f = 25
# new node g = 29
#
#
# *Faster Path* = 37
# current_node coord = [2, 13]
# current_node value = 3
# current_node g = 29
# current_node h = 25
# current_node f = 54
#
#
# coord = [1, 13]
# value = 0
# g = 3
# h = 26
# f = 29
# new node g = 32
#
#
# *Faster Path* = 25
# coord = [2, 14]
# value = 8
# g = 5
# h = 24
# f = 29
# new node g = 34
#
#
# current_node coord = [3, 12]
# current_node value = 1
# current_node g = 31
# current_node h = 25
# current_node f = 56
#
#
# current_node coord = [10, 7]
# current_node value = 3
# current_node g = 33
# current_node h = 23
# current_node f = 56
#
#
# coord = [11, 7]
# value = 1
# g = 2
# h = 22
# f = 24
# new node g = 35
#
#
# coord = [10, 8]
# value = 6
# g = 3
# h = 22
# f = 25
# new node g = 36
#
#
# current_node coord = [10, 8]
# current_node value = 6
# current_node g = 34
# current_node h = 22
# current_node f = 56
#
#
# coord = [11, 8]
# value = 5
# g = 1
# h = 21
# f = 22
# new node g = 35
#
#
# coord = [10, 9]
# value = 2
# g = 4
# h = 21
# f = 25
# new node g = 38
#
#
# current_node coord = [11, 2]
# current_node value = 3
# current_node g = 29
# current_node h = 27
# current_node f = 56
#
#
# current_node coord = [11, 8]
# current_node value = 5
# current_node g = 35
# current_node h = 21
# current_node f = 56
#
#
# coord = [12, 8]
# value = 2
# g = 3
# h = 20
# f = 23
# new node g = 38
#
#
# coord = [11, 9]
# value = 3
# g = 2
# h = 20
# f = 22
# new node g = 37
#
#
# coord = [11, 7]
# value = 1
# g = 4
# h = 22
# f = 26
# new node g = 39
#
#
# current_node coord = [12, 0]
# current_node value = 4
# current_node g = 28
# current_node h = 28
# current_node f = 56
#
#
# coord = [13, 0]
# value = 7
# g = 3
# h = 27
# f = 30
# new node g = 31
#
#
# current_node coord = [12, 8]
# current_node value = 2
# current_node g = 36
# current_node h = 20
# current_node f = 56
#
#
# coord = [12, 9]
# value = 2
# g = 0
# h = 19
# f = 19
# new node g = 36
#
#
# coord = [12, 7]
# value = 6
# g = 4
# h = 21
# f = 25
# new node g = 40
#
#
# current_node coord = [12, 9]
# current_node value = 2
# current_node g = 36
# current_node h = 19
# current_node f = 55
#
#
# coord = [13, 9]
# value = 0
# g = 2
# h = 18
# f = 20
# new node g = 38
#
#
# coord = [11, 9]
# value = 3
# g = 1
# h = 20
# f = 21
# new node g = 37
#
#
# coord = [12, 10]
# value = 3
# g = 1
# h = 18
# f = 19
# new node g = 37
#
#
# current_node coord = [12, 10]
# current_node value = 3
# current_node g = 37
# current_node h = 18
# current_node f = 55
#
#
# coord = [13, 10]
# value = 4
# g = 1
# h = 17
# f = 18
# new node g = 38
#
#
# coord = [11, 10]
# value = 7
# g = 4
# h = 19
# f = 23
# new node g = 41
#
#
# coord = [12, 11]
# value = 1
# g = 2
# h = 17
# f = 19
# new node g = 39
#
#
# current_node coord = [13, 10]
# current_node value = 4
# current_node g = 38
# current_node h = 17
# current_node f = 55
#
#
# coord = [14, 10]
# value = 1
# g = 3
# h = 16
# f = 19
# new node g = 41
#
#
# coord = [13, 11]
# value = 3
# g = 1
# h = 16
# f = 17
# new node g = 39
#
#
# coord = [13, 9]
# value = 0
# g = 4
# h = 18
# f = 22
# new node g = 42
#
#
# current_node coord = [13, 11]
# current_node value = 3
# current_node g = 39
# current_node h = 16
# current_node f = 55
#
#
# coord = [14, 11]
# value = 9
# g = 6
# h = 15
# f = 21
# new node g = 45
#
#
# coord = [12, 11]
# value = 1
# g = 2
# h = 17
# f = 19
# new node g = 41
#
#
# coord = [13, 12]
# value = 5
# g = 2
# h = 15
# f = 17
# new node g = 41
#
#
# current_node coord = [12, 11]
# current_node value = 1
# current_node g = 39
# current_node h = 17
# current_node f = 56
#
#
# coord = [11, 11]
# value = 5
# g = 4
# h = 18
# f = 22
# new node g = 43
#
#
# coord = [12, 12]
# value = 6
# g = 5
# h = 16
# f = 21
# new node g = 44
#
#
# current_node coord = [13, 9]
# current_node value = 0
# current_node g = 38
# current_node h = 18
# current_node f = 56
#
#
# coord = [14, 9]
# value = 5
# g = 5
# h = 17
# f = 22
# new node g = 43
#
#
# current_node coord = [13, 12]
# current_node value = 5
# current_node g = 41
# current_node h = 15
# current_node f = 56
#
#
# coord = [14, 12]
# value = 4
# g = 1
# h = 14
# f = 15
# new node g = 42
#
#
# coord = [12, 12]
# value = 6
# g = 1
# h = 16
# f = 17
# new node g = 42
#
#
# *Faster Path* = 42
# coord = [13, 13]
# value = 3
# g = 2
# h = 14
# f = 16
# new node g = 43
#
#
# current_node coord = [14, 4]
# current_node value = 0
# current_node g = 34
# current_node h = 22
# current_node f = 56
#
#
# coord = [15, 4]
# value = 0
# g = 0
# h = 21
# f = 21
# new node g = 34
#
#
# coord = [13, 4]
# value = 4
# g = 4
# h = 23
# f = 27
# new node g = 38
#
#
# coord = [14, 5]
# value = 3
# g = 3
# h = 21
# f = 24
# new node g = 37
#
#
# current_node coord = [15, 4]
# current_node value = 0
# current_node g = 34
# current_node h = 21
# current_node f = 55
#
#
# coord = [16, 4]
# value = 5
# g = 5
# h = 20
# f = 25
# new node g = 39
#
#
# coord = [15, 5]
# value = 9
# g = 9
# h = 20
# f = 29
# new node g = 43
#
#
# coord = [15, 3]
# value = 0
# g = 0
# h = 22
# f = 22
# new node g = 34
#
#
# current_node coord = [14, 9]
# current_node value = 5
# current_node g = 39
# current_node h = 17
# current_node f = 56
#
#
# coord = [15, 9]
# value = 6
# g = 1
# h = 16
# f = 17
# new node g = 40
#
#
# *Faster Path* = 11
# coord = [14, 10]
# value = 1
# g = 4
# h = 16
# f = 20
# new node g = 43
#
#
# current_node coord = [14, 12]
# current_node value = 4
# current_node g = 42
# current_node h = 14
# current_node f = 56
#
#
# coord = [15, 12]
# value = 0
# g = 4
# h = 13
# f = 17
# new node g = 46
#
#
# coord = [14, 13]
# value = 0
# g = 4
# h = 13
# f = 17
# new node g = 46
#
#
# coord = [14, 11]
# value = 9
# g = 5
# h = 15
# f = 20
# new node g = 47
#
#
# current_node coord = [15, 3]
# ...
# value = 0
# g = 7
# h = 13
# f = 20
# new node g = 52
#
#
# coord = [6, 19]
# value = 8
# g = 1
# h = 15
# f = 16
# new node g = 46
#
#
# current_node coord = [3, 20]
# current_node value = 1
# current_node g = 43
# current_node h = 17
# current_node f = 60
#
#
# coord = [2, 20]
# value = 1
# g = 0
# h = 18
# f = 18
# new node g = 43
#
#
# coord = [3, 19]
# value = 9
# g = 8
# h = 18
# f = 26
# new node g = 51
#
#
# current_node coord = [8, 17]
# current_node value = 3
# current_node g = 45
# current_node h = 15
# current_node f = 60
#
#
# coord = [9, 17]
# value = 5
# g = 2
# h = 14
# f = 16
# new node g = 47
#
#
# coord = [8, 18]
# value = 0
# g = 3
# h = 14
# f = 17
# new node g = 48
#
#
# current_node coord = [9, 12]
# current_node value = 9
# current_node g = 41
# current_node h = 19
# current_node f = 60
#
#
# coord = [10, 12]
# value = 9
# g = 0
# h = 18
# f = 18
# new node g = 41
#
#
# *Faster Path* = 18
# current_node coord = [10, 12]
# current_node value = 9
# current_node g = 41
# current_node h = 18
# current_node f = 59
#
#
# current_node coord = [11, 10]
# current_node value = 7
# current_node g = 41
# current_node h = 19
# current_node f = 60
#
#
# current_node coord = [14, 11]
# current_node value = 9
# current_node g = 45
# current_node h = 15
# current_node f = 60
#
#
# current_node coord = [15, 2]
# current_node value = 7
# current_node g = 37
# current_node h = 23
# current_node f = 60
#
#
# coord = [16, 2]
# value = 7
# g = 0
# h = 22
# f = 22
# new node g = 37
#
#
# current_node coord = [16, 2]
# current_node value = 7
# current_node g = 37
# current_node h = 22
# current_node f = 59
#
#
# coord = [17, 2]
# value = 8
# g = 1
# h = 21
# f = 22
# new node g = 38
#
#
# coord = [16, 3]
# value = 9
# g = 2
# h = 21
# f = 23
# new node g = 39
#
#
# *Faster Path* = 34
# coord = [16, 1]
# value = 1
# g = 6
# h = 23
# f = 29
# new node g = 43
#
#
# current_node coord = [17, 2]
# current_node value = 8
# current_node g = 38
# current_node h = 21
# current_node f = 59
#
#
# coord = [18, 2]
# value = 7
# g = 1
# h = 20
# f = 21
# new node g = 39
#
#
# coord = [17, 3]
# value = 9
# g = 1
# h = 20
# f = 21
# new node g = 39
#
#
# coord = [17, 1]
# value = 4
# g = 4
# h = 22
# f = 26
# new node g = 42
#
#
# current_node coord = [17, 3]
# current_node value = 9
# current_node g = 39
# current_node h = 20
# current_node f = 59
#
#
# coord = [18, 3]
# value = 0
# g = 9
# h = 19
# f = 28
# new node g = 48
#
#
# coord = [16, 3]
# value = 9
# g = 0
# h = 21
# f = 21
# new node g = 39
#
#
# coord = [17, 4]
# value = 7
# g = 2
# h = 19
# f = 21
# new node g = 41
#
#
# current_node coord = [18, 2]
# current_node value = 7
# current_node g = 39
# current_node h = 20
# current_node f = 59
#
#
# coord = [19, 2]
# value = 9
# g = 2
# h = 19
# f = 21
# new node g = 41
#
#
# coord = [18, 3]
# value = 0
# g = 7
# h = 19
# f = 26
# new node g = 46
#
#
# *Faster Path* = 59
# coord = [18, 1]
# value = 2
# g = 5
# h = 21
# f = 26
# new node g = 44
#
#
# current_node coord = [15, 6]
# current_node value = 3
# current_node g = 41
# current_node h = 19
# current_node f = 60
#
#
# coord = [16, 6]
# value = 2
# g = 1
# h = 18
# f = 19
# new node g = 42
#
#
# *Faster Path* = 41
# coord = [15, 5]
# value = 9
# g = 6
# h = 20
# f = 26
# new node g = 47
#
#
# current_node coord = [15, 15]
# current_node value = 4
# current_node g = 50
# current_node h = 10
# current_node f = 60
#
#
# coord = [16, 15]
# value = 3
# g = 1
# h = 9
# f = 10
# new node g = 51
#
#
# coord = [14, 15]
# value = 8
# g = 4
# h = 11
# f = 15
# new node g = 54
#
#
# coord = [15, 16]
# value = 8
# g = 4
# h = 9
# f = 13
# new node g = 54
#
#
# current_node coord = [16, 1]
# current_node value = 1
# current_node g = 37
# current_node h = 23
# current_node f = 60
#
#
# coord = [17, 1]
# value = 4
# g = 3
# h = 22
# f = 25
# new node g = 40
#
#
# *Faster Path* = 60
# coord = [16, 0]
# value = 2
# g = 1
# h = 24
# f = 25
# new node g = 38
#
#
# current_node coord = [16, 3]
# current_node value = 9
# current_node g = 39
# current_node h = 21
# current_node f = 60
#
#
# current_node coord = [16, 6]
# current_node value = 2
# current_node g = 42
# current_node h = 18
# current_node f = 60
#
#
# coord = [16, 7]
# value = 2
# g = 0
# h = 17
# f = 17
# new node g = 42
#
#
# *Faster Path* = 40
# current_node coord = [16, 7]
# current_node value = 2
# current_node g = 42
# current_node h = 17
# current_node f = 59
#
#
# coord = [16, 8]
# value = 9
# g = 7
# h = 16
# f = 23
# new node g = 49
#
#
# current_node coord = [16, 9]
# current_node value = 1
# current_node g = 45
# current_node h = 15
# current_node f = 60
#
#
# coord = [17, 9]
# value = 6
# g = 5
# h = 14
# f = 19
# new node g = 50
#
#
# coord = [16, 8]
# value = 9
# g = 8
# h = 16
# f = 24
# new node g = 53
#
#
# current_node coord = [16, 12]
# current_node value = 6
# current_node g = 48
# current_node h = 12
# current_node f = 60
#
#
# coord = [16, 13]
# value = 7
# g = 1
# h = 11
# f = 12
# new node g = 49
#
#
# *Faster Path* = 25
# current_node coord = [16, 13]
# current_node value = 7
# current_node g = 49
# current_node h = 11
# current_node f = 60
#
#
# coord = [15, 13]
# value = 6
# g = 1
# h = 12
# f = 13
# new node g = 50
#
#
# *Faster Path* = 32
# coord = [16, 14]
# value = 4
# g = 3
# h = 10
# f = 13
# new node g = 52
#
#
# current_node coord = [16, 14]
# current_node value = 4
# current_node g = 50
# current_node h = 10
# current_node f = 60
#
#
# coord = [17, 14]
# value = 0
# g = 4
# h = 9
# f = 13
# new node g = 54
#
#
# coord = [16, 15]
# value = 3
# g = 1
# h = 9
# f = 10
# new node g = 51
#
#
# current_node coord = [16, 15]
# current_node value = 3
# current_node g = 51
# current_node h = 9
# current_node f = 60
#
#
# coord = [17, 15]
# value = 2
# g = 1
# h = 8
# f = 9
# new node g = 52
#
#
# coord = [16, 16]
# value = 7
# g = 4
# h = 8
# f = 12
# new node g = 55
#
#
# current_node coord = [17, 4]
# current_node value = 7
# current_node g = 41
# current_node h = 19
# current_node f = 60
#
#
# coord = [18, 4]
# value = 9
# g = 2
# h = 18
# f = 20
# new node g = 43
#
#
# *Faster Path* = 42
# current_node coord = [17, 15]
# current_node value = 2
# current_node g = 52
# current_node h = 8
# current_node f = 60
#
#
# coord = [18, 15]
# value = 4
# g = 2
# h = 7
# f = 9
# new node g = 54
#
#
# coord = [17, 16]
# value = 7
# g = 5
# h = 7
# f = 12
# new node g = 57
#
#
# coord = [17, 14]
# value = 0
# g = 2
# h = 9
# f = 11
# new node g = 54
#
#
# current_node coord = [19, 2]
# current_node value = 9
# current_node g = 41
# current_node h = 19
# current_node f = 60
#
#
# coord = [20, 2]
# value = 9
# g = 0
# h = 18
# f = 18
# new node g = 41
#
#
# coord = [19, 3]
# value = 7
# g = 2
# h = 18
# f = 20
# new node g = 43
#
#
# coord = [19, 1]
# value = 4
# g = 5
# h = 20
# f = 25
# new node g = 46
#
#
# current_node coord = [20, 2]
# current_node value = 9
# current_node g = 41
# current_node h = 18
# current_node f = 59
#
#
# coord = [20, 3]
# value = 3
# g = 6
# h = 17
# f = 23
# new node g = 47
#
#
# coord = [20, 1]
# value = 8
# g = 1
# h = 19
# f = 20
# new node g = 42
#
#
# current_node coord = [19, 5]
# current_node value = 2
# current_node g = 44
# current_node h = 16
# current_node f = 60
#
#
# coord = [20, 5]
# value = 3
# g = 1
# h = 15
# f = 16
# new node g = 45
#
#
# coord = [19, 6]
# value = 5
# g = 3
# h = 15
# f = 18
# new node g = 47
#
#
# coord = [19, 4]
# value = 3
# g = 1
# h = 17
# f = 18
# new node g = 45
#
#
# current_node coord = [20, 5]
# current_node value = 3
# current_node g = 45
# current_node h = 15
# current_node f = 60
#
#
# coord = [20, 6]
# value = 5
# g = 2
# h = 14
# f = 16
# new node g = 47
#
#
# coord = [20, 4]
# value = 9
# g = 6
# h = 16
# f = 22
# new node g = 51
#
#
# current_node coord = [0, 9]
# current_node value = 0
# current_node g = 30
# current_node h = 31
# current_node f = 61
#
#
# current_node coord = [2, 20]
# current_node value = 1
# current_node g = 43
# current_node h = 18
# current_node f = 61
#
#
# coord = [1, 20]
# value = 1
# g = 0
# h = 19
# f = 19
# new node g = 43
#
#
# coord = [2, 19]
# value = 5
# g = 4
# h = 19
# f = 23
# new node g = 47
#
#
# current_node coord = [5, 17]
# current_node value = 7
# current_node g = 43
# current_node h = 18
# current_node f = 61
#
#
# coord = [6, 17]
# value = 9
# g = 2
# h = 17
# f = 19
# new node g = 45
#
#
# coord = [5, 18]
# value = 9
# g = 2
# h = 17
# f = 19
# new node g = 45
#
#
# *Faster Path* = 32
# current_node coord = [6, 16]
# current_node value = 7
# current_node g = 43
# current_node h = 18
# current_node f = 61
#
#
# coord = [6, 17]
# value = 9
# g = 2
# h = 17
# f = 19
# new node g = 45
#
#
# current_node coord = [6, 19]
# current_node value = 8
# current_node g = 46
# current_node h = 15
# current_node f = 61
#
#
# coord = [7, 19]
# value = 9
# g = 1
# h = 14
# f = 15
# new node g = 47
#
#
# coord = [5, 19]
# value = 8
# g = 0
# h = 16
# f = 16
# new node g = 46
#
#
# coord = [6, 18]
# value = 7
# g = 1
# h = 16
# f = 17
# new node g = 47
#
#
# current_node coord = [7, 19]
# current_node value = 9
# current_node g = 47
# current_node h = 14
# current_node f = 61
#
#
# coord = [8, 19]
# value = 9
# g = 0
# h = 13
# f = 13
# new node g = 47
#
#
# coord = [7, 20]
# value = 0
# g = 9
# h = 13
# f = 22
# new node g = 56
#
#
# coord = [7, 18]
# value = 3
# g = 6
# h = 15
# f = 21
# new node g = 53
#
#
# current_node coord = [8, 19]
# current_node value = 9
# current_node g = 47
# current_node h = 13
# current_node f = 60
#
#
# coord = [9, 19]
# value = 6
# g = 3
# h = 12
# f = 15
# new node g = 50
#
#
# coord = [8, 20]
# value = 8
# g = 1
# h = 12
# f = 13
# new node g = 48
#
#
# coord = [8, 18]
# value = 0
# g = 9
# h = 14
# f = 23
# new node g = 56
#
#
# current_node coord = [8, 20]
# current_node value = 8
# current_node g = 48
# current_node h = 12
# current_node f = 60
#
#
# coord = [9, 20]
# value = 1
# g = 7
# h = 11
# f = 18
# new node g = 55
#
#
# coord = [7, 20]
# value = 0
# g = 8
# h = 13
# f = 21
# new node g = 56
#
#
# current_node coord = [9, 17]
# current_node value = 5
# current_node g = 47
# current_node h = 14
# current_node f = 61
#
#
# coord = [10, 17]
# value = 1
# g = 4
# h = 13
# f = 17
# new node g = 51
#
#
# coord = [9, 18]
# value = 9
# g = 4
# h = 13
# f = 17
# new node g = 51
#
#
# coord = [9, 16]
# value = 0
# g = 5
# h = 15
# f = 20
# new node g = 52
#
#
# current_node coord = [12, 13]
# current_node value = 0
# current_node g = 46
# current_node h = 15
# current_node f = 61
#
#
# current_node coord = [12, 16]
# current_node value = 9
# current_node g = 49
# current_node h = 12
# current_node f = 61
#
#
# coord = [13, 16]
# value = 0
# g = 9
# h = 11
# f = 20
# new node g = 58
#
#
# coord = [11, 16]
# value = 7
# g = 2
# h = 13
# f = 15
# new node g = 51
#
#
# coord = [12, 17]
# value = 9
# g = 0
# h = 11
# f = 11
# new node g = 49
#
#
# current_node coord = [12, 17]
# current_node value = 9
# current_node g = 49
# current_node h = 11
# current_node f = 60
#
#
# coord = [13, 17]
# value = 1
# g = 8
# h = 10
# f = 18
# new node g = 57
#
#
# coord = [11, 17]
# value = 3
# g = 6
# h = 12
# f = 18
# new node g = 55
#
#
# coord = [12, 18]
# value = 9
# g = 0
# h = 10
# f = 10
# new node g = 49
#
#
# current_node coord = [12, 18]
# current_node value = 9
# current_node g = 49
# current_node h = 10
# current_node f = 59
#
#
# coord = [13, 18]
# value = 8
# g = 1
# h = 9
# f = 10
# new node g = 50
#
#
# coord = [11, 18]
# value = 4
# g = 5
# h = 11
# f = 16
# new node g = 54
#
#
# coord = [12, 19]
# value = 2
# g = 7
# h = 9
# f = 16
# new node g = 56
#
#
# current_node coord = [13, 18]
# current_node value = 8
# current_node g = 50
# current_node h = 9
# current_node f = 59
#
#
# coord = [14, 18]
# value = 7
# g = 1
# h = 8
# f = 9
# new node g = 51
#
#
# coord = [13, 19]
# value = 9
# g = 1
# h = 8
# f = 9
# new node g = 51
#
#
# coord = [13, 17]
# value = 1
# g = 7
# h = 10
# f = 17
# new node g = 57
#
#
# current_node coord = [13, 19]
# current_node value = 9
# current_node g = 51
# current_node h = 8
# current_node f = 59
#
#
# coord = [14, 19]
# value = 4
# g = 5
# h = 7
# f = 12
# new node g = 56
#
#
# coord = [12, 19]
# value = 2
# g = 7
# h = 9
# f = 16
# new node g = 58
#
#
# coord = [13, 20]
# value = 9
# g = 0
# h = 7
# f = 7
# new node g = 51
#
#
# current_node coord = [13, 20]
# current_node value = 9
# current_node g = 51
# current_node h = 7
# current_node f = 58
#
#
# coord = [14, 20]
# value = 4
# g = 5
# h = 6
# f = 11
# new node g = 56
#
#
# coord = [12, 20]
# value = 0
# g = 9
# h = 8
# f = 17
# new node g = 60
#
#
# current_node coord = [14, 18]
# current_node value = 7
# current_node g = 51
# current_node h = 8
# current_node f = 59
#
#
# coord = [15, 18]
# value = 1
# g = 6
# h = 7
# f = 13
# new node g = 57
#
#
# coord = [14, 19]
# value = 4
# g = 3
# h = 7
# f = 10
# new node g = 54
#
#
# *Faster Path* = 68
# coord = [14, 17]
# value = 6
# g = 1
# h = 9
# f = 10
# new node g = 52
#
#
# current_node coord = [13, 15]
# current_node value = 1
# current_node g = 49
# current_node h = 12
# current_node f = 61
#
#
# coord = [14, 15]
# value = 8
# g = 7
# h = 11
# f = 18
# new node g = 56
#
#
# coord = [13, 16]
# value = 0
# g = 1
# h = 11
# f = 12
# new node g = 50
#
#
# *Faster Path* = 61
# current_node coord = [13, 16]
# current_node value = 0
# current_node g = 50
# current_node h = 11
# current_node f = 61
#
#
# coord = [14, 16]
# value = 1
# g = 1
# h = 10
# f = 11
# new node g = 51
#
#
# coord = [13, 17]
# value = 1
# g = 1
# h = 10
# f = 11
# new node g = 51
#
#
# *Faster Path* = 62
# current_node coord = [13, 17]
# current_node value = 1
# current_node g = 51
# current_node h = 10
# current_node f = 61
#
#
# coord = [14, 17]
# value = 6
# g = 5
# h = 9
# f = 14
# new node g = 56
#
#
# current_node coord = [14, 16]
# current_node value = 1
# current_node g = 51
# current_node h = 10
# current_node f = 61
#
#
# coord = [15, 16]
# value = 8
# g = 7
# h = 9
# f = 16
# new node g = 58
#
#
# coord = [14, 17]
# value = 6
# g = 5
# h = 9
# f = 14
# new node g = 56
#
#
# coord = [14, 15]
# value = 8
# g = 7
# h = 11
# f = 18
# new node g = 58
#
#
# current_node coord = [14, 17]
# current_node value = 6
# current_node g = 52
# current_node h = 9
# current_node f = 61
#
#
# coord = [15, 17]
# value = 3
# g = 3
# h = 8
# f = 11
# new node g = 55
#
#
# current_node coord = [14, 19]
# current_node value = 4
# current_node g = 54
# current_node h = 7
# current_node f = 61
#
#
# coord = [15, 19]
# value = 5
# g = 1
# h = 6
# f = 7
# new node g = 55
#
#
# coord = [14, 20]
# value = 4
# g = 0
# h = 6
# f = 6
# new node g = 54
#
#
# *Faster Path* = 33
# current_node coord = [14, 20]
# current_node value = 4
# current_node g = 54
# current_node h = 6
# current_node f = 60
#
#
# coord = [15, 20]
# value = 0
# g = 4
# h = 5
# f = 9
# new node g = 58
#
#
# current_node coord = [15, 0]
# current_node value = 2
# current_node g = 36
# current_node h = 25
# current_node f = 61
#
#
# coord = [16, 0]
# value = 2
# g = 0
# h = 24
# f = 24
# new node g = 36
#
#
# *Faster Path* = 16
# current_node coord = [16, 0]
# current_node value = 2
# current_node g = 36
# current_node h = 24
# current_node f = 60
#
#
# coord = [17, 0]
# value = 8
# g = 6
# h = 23
# f = 29
# new node g = 42
#
#
# current_node coord = [15, 19]
# current_node value = 5
# current_node g = 55
# current_node h = 6
# current_node f = 61
#
#
# coord = [16, 19]
# value = 6
# g = 1
# h = 5
# f = 6
# new node g = 56
#
#
# coord = [15, 20]
# value = 0
# g = 5
# h = 5
# f = 10
# new node g = 60
#
#
# coord = [15, 18]
# value = 1
# g = 4
# h = 7
# f = 11
# new node g = 59
#
#
# current_node coord = [16, 8]
# current_node value = 9
# current_node g = 45
# current_node h = 16
# current_node f = 61
#
#
# coord = [17, 8]
# value = 2
# g = 7
# h = 15
# f = 22
# new node g = 52
#
#
# current_node coord = [16, 19]
# current_node value = 6
# current_node g = 56
# current_node h = 5
# current_node f = 61
#
#
# coord = [17, 19]
# value = 5
# g = 1
# h = 4
# f = 5
# new node g = 57
#
#
# coord = [16, 20]
# value = 6
# g = 0
# h = 4
# f = 4
# new node g = 56
#
#
# coord = [16, 18]
# value = 1
# g = 5
# h = 6
# f = 11
# new node g = 61
#
#
# current_node coord = [16, 20]
# current_node value = 6
# current_node g = 56
# current_node h = 4
# current_node f = 60
#
#
# coord = [17, 20]
# value = 5
# g = 1
# h = 3
# f = 4
# new node g = 57
#
#
# coord = [15, 20]
# value = 0
# g = 6
# h = 5
# f = 11
# new node g = 62
#
#
# current_node coord = [17, 20]
# current_node value = 5
# current_node g = 57
# current_node h = 3
# current_node f = 60
#
#
# coord = [18, 20]
# value = 6
# g = 1
# h = 2
# f = 3
# new node g = 58
#
#
# coord = [17, 19]
# value = 5
# g = 0
# h = 4
# f = 4
# new node g = 57
#
#
# current_node coord = [18, 20]
# current_node value = 6
# current_node g = 58
# current_node h = 2
# current_node f = 60
#
#
# coord = [19, 20]
# value = 6
# g = 0
# h = 1
# f = 1
# new node g = 58
#
#
# coord = [18, 19]
# value = 3
# g = 3
# h = 3
# f = 6
# new node g = 61
#
#
# current_node coord = [19, 20]
# current_node value = 6
# current_node g = 58
# current_node h = 1
# current_node f = 59
#
#
# coord = [20, 20]
# value = 7
# g = 1
# h = 0
# f = 1
# new node g = 59
#
#
# coord = [19, 19]
# value = 7
# g = 1
# h = 2
# f = 3
# new node g = 59
#
#
# current_node coord = [20, 20]
# current_node value = 7
# current_node g = 59
# current_node h = 0
# current_node f = 59
#
#
# [20, 20]
# 0
# 59
# 7
# ******
# [19, 20]
# 1
# 58
# 6
# ******
# [18, 20]
# 1
# 58
# 6
# ******
# [17, 20]
# 2
# 57
# 5
# ******
# [16, 20]
# 3
# 56
# 6
# ******
# [16, 19]
# 3
# 56
# 6
# ******
# [15, 19]
# 4
# 55
# 5
# ******
# [14, 19]
# 5
# 54
# 4
# ******
# [14, 18]
# 8
# 51
# 7
# ******
# [13, 18]
# 9
# 50
# 8
# ******
# [12, 18]
# 10
# 49
# 9
# ******
# [12, 17]
# 10
# 49
# 9
# ******
# [12, 16]
# 10
# 49
# 9
# ******
# [12, 15]
# 14
# 45
# 5
# ******
# [12, 14]
# 16
# 43
# 7
# ******
# [11, 14]
# 17
# 42
# 6
# ******
# [10, 14]
# 23
# 36
# 0
# ******
# [9, 14]
# 24
# 35
# 1
# ******
# [9, 13]
# 24
# 35
# 1
# ******
# [8, 13]
# 25
# 34
# 0
# ******
# [7, 13]
# 26
# 33
# 1
# ******
# [6, 13]
# 26
# 33
# 1
# ******
# [6, 12]
# 27
# 32
# 0
# ******
# [6, 11]
# 30
# 29
# 3
# ******
# [5, 11]
# 33
# 26
# 6
# ******
# [4, 11]
# 34
# 25
# 7
# ******
# [4, 10]
# 35
# 24
# 8
# ******
# [4, 9]
# 36
# 23
# 9
# ******
# [4, 8]
# 41
# 18
# 4
# ******
# [5, 8]
# 41
# 18
# 4
# ******
# [5, 7]
# 41
# 18
# 4
# ******
# [5, 6]
# 42
# 17
# 5
# ******
# [5, 5]
# 43
# 16
# 4
# ******
# [5, 4]
# 45
# 14
# 2
# ******
# [5, 3]
# 46
# 13
# 3
# ******
# [5, 2]
# 47
# 12
# 2
# ******
# [4, 2]
# 48
# 11
# 3
# ******
# [3, 2]
# 48
# 11
# 3
# ******
# [2, 2]
# 50
# 9
# 1
# ******
# [2, 1]
# 55
# 4
# 6
# ******
# [1, 1]
# 57
# 2
# 4
# ******
# [0, 1]
# 59
# 0
# 2
# ******
# None
# 59
# 59
